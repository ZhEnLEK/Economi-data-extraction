# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
df = pd.ExcelFile('JADUAL MMS JANUARI 2022.xlsx')

# %%
df.sheet_names
# Out:
# ['Jadual 1',
#  'Jadual 1.1a',
#  'Jadual 1.1b',
#  'Jadual 1.1c',
#  'Jadual 1.2a',
#  'Jadual 1.2b ',
#  'Jadual 1.2c',
#  'Jadual 1.3a',
#  'Jadual 1.3b',
#  'Jadual 1.3c',
#  'Jadual 1.4a ',
#  'Jadual 1.4b',
#  'Jadual 1.4c',
#  'Jadual 1.5a',
#  'Jadual 1.5b',
#  'Jadual 1.5c',
#  'Jadual 1.6a',
#  'Jadual 1.6b',
#  'Jadual 1.6c',
#  'Jadual 2 ',
#  'Data Pelarasan Musim']

# %%
df1 = df.parse(0, header = 11)

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2  Data Asal (Original Data)    % \nYoY  \
# 0         NaN         NaN        NaN                        NaN        NaN
# 1         NaN      2019.0        NaN               1.376027e+06        NaN
# 2         NaN      2020.0        NaN               1.346620e+06  -2.137154
# 3         NaN      2021.0        NaN               1.554738e+06  15.454903
# 4         NaN         NaN        NaN                        NaN        NaN
#
#    Pelarasan Musim (Seasonally Adjusted)  % MoM  Data Asal (Original Data).1  \
# 0                                    NaN    NaN                          NaN
# 1                                    NaN    NaN                 2.243788e+06
# 2                                    NaN    NaN                 2.199195e+06
# 3                                    NaN    NaN                 2.259619e+06
# 4                                    NaN    NaN                          NaN
#
# ...

# %%
df1.tail(50)
# Out:
#     Unnamed: 0  Unnamed: 1          Unnamed: 2  Data Asal (Original Data)  \
# 10         NaN      2020.0                  Q1              339323.806504
# 11         NaN         NaN                  Q2              282020.407288
# 12         NaN         NaN                  Q3              358828.248263
# 13         NaN         NaN                  Q4              366447.107873
# 14         NaN         NaN                 NaN                        NaN
# 15         NaN      2021.0                  Q1              368234.123944
# 16         NaN         NaN                  Q2              377734.568483
# 17         NaN         NaN                  Q3              381793.337328
# 18         NaN         NaN                  Q4              426976.282385
# 19         NaN         NaN                 NaN                        NaN
# 20         NaN      2019.0                Jan.              115203.287583
# 21         NaN         NaN                Feb.              103380.864542
# ...

# %%
df1.iloc[:,1]
# Out:
# 0        NaN
# 1     2019.0
# 2     2020.0
# 3     2021.0
# 4        NaN
# 5     2019.0
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10    2020.0
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15    2021.0
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20    2019.0
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33    2020.0
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46    2021.0
# 47       NaN
# 48       NaN
# 49       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
# 54       NaN
# 55       NaN
# 56       NaN
# 57       NaN
# 58       NaN
# 59    2022.0
# Name: Unnamed: 1, dtype: float64

# %%
df1.iloc[22,2]
# Out:
# ' Mac'

# %%
import re
#valids = re.sub(r"[^A-Za-z]+", '', my_string)

re.sub(r"[^A-Za-z]+", '', df1.iloc[20,2])
# Out:
# 'Jan'

# %%
def monthToNum(Month):
    return {
            'Jan': 1,
            'Feb': 2,
            'Mac': 3,
            'Apr': 4,
            'April': 4,
            'Mei': 5,
            'Jun': 6,
            'Jul': 7,
            'Ogo': 8,
            'Sep': 9, 
            'Sept': 9, 
            'Okt': 10,
            'Nov': 11,
            'Dis': 12
    }[Month]

# %%
monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[20,2]))
# Out:
# 1

# %%
monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8924/3673377327.py in <module>
# ----> 1 monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2]))
#
# NameError: name 'i' is not defined

# %%
n=20
for i in range(n, n+12):
    print(int(df1.iloc[20,1]) ,df1.iloc[i, 2], df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
n+=1
for i in range(n, n+12):
    print(int(df1.iloc[33,1]) ,df1.iloc[i, 2], df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
    
n+=1
for i in range(n, n+12):
    print(int(df1.iloc[46,1]) ,df1.iloc[i, 2], df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
    
print(int(df1.iloc[59,1]) ,df1.iloc[59, 2], df1.iloc[59, 5],df1.iloc[59, 6], n)
# Out:
# 2019      Jan. 112799.53 nan 20
# 2019 Feb. 112899.415 0.08855090087698159 21
# 2019  Mac 113199.97 0.2662148426544064 22
# 2019 April 117299.977 3.6219152708256104 23
# 2019              Mei 116600.443 -0.5963632882894814 24
# 2019              Jun 115499.778 -0.9439629659039923 25
# 2019              Jul. 116000.258 0.4333168501847666 26
# 2019              Ogo. 114500.02 -1.2933057441992872 27
# 2019              Sept. 113899.831 -0.5241824411908311 28
# 2019              Okt. 114300.26 0.3515624180337795 29
# 2019              Nov. 114100.551 -0.17472313711270715 30
# 2019              Dis. 114800.012 0.6130215795364506 31
# 2020      Jan. 115199.486 0.347973831222248 33
# 2020 Feb. 121800.601 5.730160115471335 34
# 2020  Mac 110100.203 -9.60619069523311 35
# 2020 Apr. 78579.944 -28.628701983410508 36
# 2020 Mei 92849.585 18.159393190710333 37
# 2020 Jun 120799.453 30.102307942464137 38
# 2020 Jul. 117900.308 -2.3999653375913823 39
# ...

# %%
n=20
for i in range(n, n+12):
    print(int(df1.iloc[20,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
n+=1
for i in range(n, n+12):
    print(int(df1.iloc[33,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
    
n+=1
for i in range(n, n+12):
    print(int(df1.iloc[46,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
    n+=1
    
print(int(df1.iloc[59,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[59,2])), df1.iloc[59, 5],df1.iloc[59, 6], n)
# Out:
# 2019 1 112799.53 nan 20
# 2019 2 112899.415 0.08855090087698159 21
# 2019 3 113199.97 0.2662148426544064 22
# 2019 4 117299.977 3.6219152708256104 23
# 2019 5 116600.443 -0.5963632882894814 24
# 2019 6 115499.778 -0.9439629659039923 25
# 2019 7 116000.258 0.4333168501847666 26
# 2019 8 114500.02 -1.2933057441992872 27
# 2019 9 113899.831 -0.5241824411908311 28
# 2019 10 114300.26 0.3515624180337795 29
# 2019 11 114100.551 -0.17472313711270715 30
# 2019 12 114800.012 0.6130215795364506 31
# 2020 1 115199.486 0.347973831222248 33
# 2020 2 121800.601 5.730160115471335 34
# 2020 3 110100.203 -9.60619069523311 35
# 2020 4 78579.944 -28.628701983410508 36
# 2020 5 92849.585 18.159393190710333 37
# 2020 6 120799.453 30.102307942464137 38
# 2020 7 117900.308 -2.3999653375913823 39
# 2020 8 116099.817 -1.5271300224253963 40
# 2020 9 117999.993 1.6366744143963672 41
# 2020 10 116800.093 -1.0168644671021383 42
# 2020 11 116800.234 0.00012071908197697212 43
# ...

# %%
import sqlite3
from sqlite3 import Error


def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection(r"C:\Users\zhenl\Desktop\sqlite\pythonsqlite.db")
# Out:
# 2.6.0

# %%
import sqlite3
from sqlite3 import Error

# Create database
def create_connection(db_file):
    """ create a database connection to a SQLite database """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()


if __name__ == '__main__':
    create_connection(r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db")
# Out:
# 2.6.0

# %%
if __name__ == '__main__':
    create_connection(r"C:\Users\zhenl\Downloads\chinook\chinook.db")
# Out:
# 2.6.0

# %%
conn2 = sqlite3.connect('chinook.db')

# %%
conn2

# %%
conn

# %%
conn

# %%
conn2

# %%
import sqlite3
from sqlite3 import Error

#Create table

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    sql_create_manufacturing_table = """ CREATE TABLE IF NOT EXISTS manufacturing (
                                        ID smallint PRIMARY KEY,
                                        Indicator_ID smallint NOT NULL,
                                        Country_ID smallint NOT NULL,
                                        Year smallint NOT NULL,
                                        Month smallint NOT NULL,
                                        Value_RM_millions float,
                                        Is_percentage bit NOT NULL,
                                        Is_M2M bit,
                                        Is_Y2Y bit,
                                        Date_Created datetime,
                                        Created_By smallint NOT NULL,
                                        Date_Modified datetime,
                                        Modified_By,
                                        Is_Active smallint NOT NULL,
                                        Is_Delete smallint NOT NULL
                                        
                                    ); """

   
    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_manufacturing_table)

        # create tasks table
       # create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()

# %%
import sqlite3
from sqlite3 import Error
from datetime import date, datetime


# Insert data
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def create_manufacturing(conn, manufacturing):
    """
    Create a new project into the  table
    :param conn:
    :param :
    :return:  id
    """
    sql = ''' INSERT INTO manufacturing(Indicator_ID, Country_ID, Year, Month, Value_RM_millions, Is_percentage, Is_M2M, Is_Y2Y, Date_Created, Created_By, Date_Modified, Modified_By, Is_Active, Is_Delete)
              VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, manufacturing)
    conn.commit()
    return cur.lastrowid





def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        # create manufacturing
       # manufacturing = ('',  '');
        #create_manufacturing(conn, manufacturing)
        n=20
        
        for i in range(n, n+12):
            manufacturing = (7, 1, int(df1.iloc[20,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5], 0, 0, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            manufacturing = (7, 1, int(df1.iloc[20,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 6], 1, 1, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            n+=1
        n+=1
        for i in range(n, n+12):
            manufacturing = (7, 1, int(df1.iloc[33,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5], 0, 0, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            manufacturing = (7, 1, int(df1.iloc[33,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 6], 1, 1, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            manufacturing = (7, 1, int(df1.iloc[33,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])),100*(df1.iloc[i, 5]- df1.iloc[i-13, 5])/df1.iloc[i-13, 5] , 1, 0, 1, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            n+=1
        n+=1
        for i in range(n, n+12):
            manufacturing = (7, 1, int(df1.iloc[46,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5], 0, 0, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            manufacturing = (7, 1, int(df1.iloc[46,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 6], 1, 1, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            manufacturing = (7, 1, int(df1.iloc[46,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])),100*(df1.iloc[i, 5]- df1.iloc[i-13, 5])/df1.iloc[i-13, 5] , 1, 0, 1, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_manufacturing(conn, manufacturing)
            n+=1
        manufacturing = (7, 1, int(df1.iloc[59,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[59,2])), df1.iloc[59, 6], 1, 1, 0, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
        create_manufacturing(conn, manufacturing)
        manufacturing = (7, 1, int(df1.iloc[59,1]), monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[59,2])),100*(df1.iloc[59, 5]- df1.iloc[59-13, 5])/df1.iloc[59-13, 5] , 1, 0, 1, "-",1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
        create_manufacturing(conn, manufacturing)
        
            
        
    
#for i in range(n, n+12):
#    print(int(df1.iloc[20,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
#    n+=1
#n+=1
#for i in range(n, n+12):
#    print(int(df1.iloc[33,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
#    n+=1
    
#n+=1
#for i in range(n, n+12):
#    print(int(df1.iloc[46,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[i,2])), df1.iloc[i, 5],df1.iloc[i, 6], n)
#    n+=1
    
#print(int(df1.iloc[59,1]) , monthToNum(re.sub(r"[^A-Za-z]+", '', df1.iloc[59,2])), df1.iloc[59, 5],df1.iloc[59, 6], n)

        # tasks
       # task_1 = ('Analyze the requirements of the app', 1, 1, project_id, '2015-01-01', '2015-01-02')
        #task_2 = ('Confirm with user about the top requirements', 1, 1, project_id, '2015-01-03', '2015-01-05')

        # create tasks
        #create_task(conn, task_1)
        #create_task(conn, task_2)


if __name__ == '__main__':
    main()
