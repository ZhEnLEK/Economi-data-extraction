# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
#from datetime import date

# %%
#date.today().year

# %%
df = pd.ExcelFile('Annual GDP 2015-2020 Tables.xlsx')

# %%
#df = pd.ExcelFile('GDP Q2 2021 Tables.xlsx')

# %%
df.sheet_names
# Out:
# ['kosong (0)',
#  'DATA MAKRO',
#  'Jadual Ringkasan',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  'kosong (1)',
#  '8',
#  '9',
#  '10',
#  '11',
#  '12',
#  '13']

# %%
df.sheet_names[0]
# Out:
# 'kosong (0)'

# %%
#df.parse('DATA MAKRO').head(50)

# %%
df1 = df.parse('DATA MAKRO', header = 3)
df1.head(50)
# Out:
#     Unnamed: 0                                        Unnamed: 1  \
# 0          NaN                                               NaN
# 1          NaN                                               NaN
# 2          NaN                                               NaN
# 3          NaN                  KDNK pada harga malar 2015\n\n\n
# 4          NaN                                               NaN
# 5          NaN                                               NaN
# 6          NaN                                               NaN
# 7          NaN                                               NaN
# 8          NaN                                               NaN
# 9          NaN    Permintaan domestik pada harga malar 2015 \n\n
# 10         NaN                                               NaN
# 11         NaN                                               NaN
# 12         NaN                                               NaN
# ...

# %%
df1[2020][4]
# Out:
# 99.4

# %%
df1['Unnamed: 13'][4]
# Out:
# 'Agriculture'

# %%
print('GDP absolute value')
for year in range(2015, 2021):
    n=1
    for i in range(4, 9):
        print(year, n, df1['Unnamed: 13'][i], df1[year][i])
        n+=1
# Out:
# GDP absolute value
# 2015 1 Agriculture 97.5
# 2015 2 Mining and quarrying 103.1
# 2015 3 Manufacturing 262.4
# 2015 4 Construction 55.4
# 2015 5 Services
#  643.9
# 2016 1 Agriculture 94.0
# 2016 2 Mining and quarrying 105.4
# 2016 3 Manufacturing 273.9
# 2016 4 Construction 59.5
# 2016 5 Services
#  680.6
# 2017 1 Agriculture 99.5
# 2017 2 Mining and quarrying 105.8
# 2017 3 Manufacturing 290.5
# 2017 4 Construction 63.5
# 2017 5 Services
#  723.4
# 2018 1 Agriculture 99.6
# 2018 2 Mining and quarrying 103.6
# 2018 3 Manufacturing 304.8
# 2018 4 Construction 66.2
# 2018 5 Services
#  773.0
# 2019 1 Agriculture 101.6
# 2019 2 Mining and quarrying 102.9
# 2019 3 Manufacturing 316.3
# 2019 4 Construction 66.5
# 2019 5 Services
#  820.9
# 2020 1 Agriculture 99.4
# 2020 2 Mining and quarrying 92.0
# 2020 3 Manufacturing 307.9
# 2020 4 Construction 53.6
# 2020 5 Services
#  775.7

# %%
print('GDP growth')
for year in range(2016, 2021):
    for i in range(28, 33):
        print(year, df1['Unnamed: 13'][i], df1[year][i])
# Out:
# GDP growth
# 2016 Agriculture -3.7
# 2016 Mining and quarrying 2.2
# 2016 Manufacturing 4.4
# 2016 Construction 7.4
# 2016 Services 5.7
# 2017 Agriculture 5.9
# 2017 Mining and quarrying 0.4
# 2017 Manufacturing 6.0
# 2017 Construction 6.7
# 2017 Services 6.3
# 2018 Agriculture 0.1
# 2018 Mining and quarrying -2.2
# 2018 Manufacturing 5.0
# 2018 Construction 4.2
# 2018 Services 6.9
# 2019 Agriculture 2.0
# 2019 Mining and quarrying -0.6
# 2019 Manufacturing 3.8
# 2019 Construction 0.4
# 2019 Services 6.2
# 2020 Agriculture -2.2
# 2020 Mining and quarrying -10.6
# 2020 Manufacturing -2.6
# 2020 Construction -19.4
# 2020 Services -5.5

# %%
df2 = df.parse('5', header=4)
df2.head(50)
# Out:
#     Unnamed: 0 Jenis aktiviti ekonomi\nKind of economic activity  \
# 0          NaN                                               NaN
# 1          NaN                                                1.
# 2          NaN                                               NaN
# 3          NaN                                               NaN
# 4          NaN                                               NaN
# 5          NaN                                               NaN
# 6          NaN                                               NaN
# 7          NaN                                               NaN
# 8          NaN                                               NaN
# 9          NaN                                               NaN
# 10         NaN                                               NaN
# 11         NaN                                               NaN
# 12         NaN                                               NaN
# ...

# %%
df2.iloc[1].dropna().iloc[0]
# Out:
# '1.'

# %%
df2.iloc[1][pd.to_numeric(df2.iloc[1], errors = 'coerce').isnull()].dropna()
# Out:
# Unnamed: 2    Pertanian\nAgriculture
# Name: 1, dtype: object

# %%
pd.to_numeric(df2.iloc[1], errors = 'coerce').dropna().iloc[-1]
# Out:
# -2.2

# %%
df2.iloc[1]#.dropna()
# Out:
# Unnamed: 0                                                              NaN
# Jenis aktiviti ekonomi\nKind of economic activity                        1.
# Unnamed: 2                                           Pertanian\nAgriculture
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              NaN
# Unnamed: 5                                                              NaN
# Unnamed: 6                                                              NaN
# Unnamed: 7                                                              NaN
# 2016                                                                   -3.7
# 2017                                                                    5.9
# 2018                                                                    0.1
# 2019e                                                                   2.0
# ...

# %%
df2.iloc[1].dropna()
# Out:
# Jenis aktiviti ekonomi\nKind of economic activity                        1.
# Unnamed: 2                                           Pertanian\nAgriculture
# 2016                                                                   -3.7
# 2017                                                                    5.9
# 2018                                                                    0.1
# 2019e                                                                   2.0
# 2020p                                                                  -2.2
# Name: 1, dtype: object

# %%
df2.iloc[1].dropna().iloc[1]
# Out:
# 'Pertanian\nAgriculture'

# %%
df.sheet_names['5']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/585669775.py in <module>
# ----> 1 df.sheet_names['5']
#
# TypeError: list indices must be integers or slices, not str

# %%
#df1['Unnamed: 42'].drop([3]).dropna() - df1['Unnamed: 41'].drop([3]).dropna()

# %%
df1.iloc[2].dropna().astype(int)

# %%
df1.iloc[2].dropna()[-1]

# %%
years = df1.iloc[2].dropna().astype(int)

# %%
years

# %%
years.drop(years.index[0], inplace = True) #removing the first element

# %%
years

# %%
#years[years.apply(lambda x: isinstance(x, int))]

# %%
#max(years[years.apply(lambda x: isinstance(x, int))])

# %%
latest_year = df1.iloc[2].dropna()[-1].astype(int)
latest_year
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/2731083941.py in <module>
# ----> 1 latest_year = df1.iloc[2].dropna()[-1].astype(int)
#       2 latest_year
#
# c:\users\zhenl\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     937
#     938         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 939             return self._values[key]
#     940
#     941         elif key_is_scalar:
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
for year in years:
    print(year)

# %%
#df1.iloc[2].dropna()[-1]

# %%
#previous_year = df1.iloc[2].dropna()[-2]
#previous_year

# %%
#df1.iloc[2][df1.iloc[2] == latest_year].index

# %%
df1.iloc[2][df1.iloc[2] == latest_year].index[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/3000091771.py in <module>
# ----> 1 df1.iloc[2][df1.iloc[2] == latest_year].index[-1]
#
# NameError: name 'latest_year' is not defined

# %%
#df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1]

# %%
df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == latest_year].index[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/2015587112.py in <module>
# ----> 1 df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == latest_year].index[-1])
#
# NameError: name 'latest_year' is not defined

# %%
for year in years:
    print(year)
    year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])
    print(year_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/2678697947.py in <module>
# ----> 1 for year in years:
#       2     print(year)
#       3     year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])
#       4     print(year_index)
#
# NameError: name 'years' is not defined

# %%
#df1.columns.get_loc(df1.iloc[3] == df1.iloc[3].dropna()[-1])

# %%
#index_latest_quarter =  max(df1.iloc[3][df1.iloc[3] == latest_quarter].index)

# %%
index_latest_year = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == latest_year].index[-1])
index_latest_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17436/860645513.py in <module>
# ----> 1 index_latest_year = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == latest_year].index[-1])
#       2 index_latest_year
#
# NameError: name 'latest_year' is not defined

# %%
#index_previous_quarter =  max(df1.iloc[3][df1.iloc[3] == previous_quarter].index)

# %%
#index_previous_quarter

# %%
#df1.iloc[3][index_latest_quarter]

# %%
#df1.iloc[13].dropna()[-1]

# %%
"""
print('\033[1m','Latest year:', latest_year,'\033[0m')

print('\033[1m','Annual growth rate GDP:','\033[0m')
gdp = []
for i in range(31,36):
    print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_year],'%')
    gdp.append([df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_year]])
    
#for i in range(20,27):
 #   print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter])
 
"""
# Out:
# "\nprint('\x1b','Latest year:', latest_year,'\x1b')\n\nprint('\x1b','Annual growth rate GDP:','\x1b')\ngdp = []\nfor i in range(31,36):\n    print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_year],'%')\n    gdp.append([df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_year]])\n    \n#for i in range(20,27):\n #   print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter])\n \n"

# %%
#print('\033[1m','Latest year:', latest_year,'\033[0m')

print('\033[1m','Annual growth rate GDP:','\033[0m')
gdp = []
for year in years:
    print('\033[1m','Year:', year,'\033[0m')
    year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])
    for i in range(31,36):
        print(df1.iloc[i].dropna()[-1], df1.iloc[i][year_index],'%')
        gdp.append([df1.iloc[i].dropna()[-1], df1.iloc[i][year_index]])
# Out:
#  Annual growth rate GDP:

# %%
#gdp

# %%
df_gdp = pd.DataFrame(gdp, columns = ['Subsector', 'AnnualGrowthRate'] )
df_gdp
# Out:
# Empty DataFrame
# Columns: [Subsector, AnnualGrowthRate]
# Index: []

# %%
#df_gdp.columns = ['Subsector', 'AnnualGrowthRate']

# %%
#df_gdp['Subsector']

# %%
#df_gdp['AnnualGrowthRate']

# %%
for index, row in df_gdp.iterrows():
    print(index+1, row.Subsector, row.AnnualGrowthRate)

# %%
#from datetime import date, datetime

# %%
#now = datetime.now()
#now.strftime('%Y/%m/%d %H:%M:%S')

# %%
#datetime.now().strftime('%Y/%m/%d %H:%M:%S')

# %%
#datetime.now().strftime('%Y/%m/%d %H:%M:%S')

# %%
#today = date.today()
#today

# %%
#type(today)

# %%
#import os, time

# %%
#time.ctime(os.path.getmtime("C:/Users/zhenl/Desktop/Kit Loong/Economic data and python file/Annual GDP 2015-2020 Tables.xlsx"))

# %%
#time.ctime(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx"))

# %%
#os.path.getctime("Annual GDP 2015-2020 Tables.xlsx")

# %%
#datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx"))

# %%
#os.stat("C:/Users/zhenl/Desktop/Kit Loong/Economic data and python file/Annual GDP 2015-2020 Tables.xlsx")

# %%
"""
import pyodbc
from datetime import date, datetime
import os, time

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

for index, row in df_gdp.iterrows():
    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
                    1,index+1,1, int(latest_year),-1, row.AnnualGrowthRate,0, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
cnxn.commit()
cursor.close()
"""
# Out:
# '\nimport pyodbc\nfrom datetime import date, datetime\nimport os, time\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_gdp.iterrows():\n   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n    #                index+1, row.AnnualGrowthRate)\n\nfor index, row in df_gdp.iterrows():\n    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n                    1,index+1,1, int(latest_year),-1, row.AnnualGrowthRate,0, datetime.now().strftime(\'%
# ...

# %%
#from itertools import cycle, islice

#cycle(range(1,6))

# %%
#list(islice(cycle(range(1,6)), 8))

# %%
#for i in range(1, 6):
#    print(i)

# %% [markdown]
# Push data into SQLite database

# %%
import sqlite3
from sqlite3 import Error

#Create table

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    sql_create_GDP_table = """ CREATE TABLE IF NOT EXISTS GDP (
                                        ID smallint PRIMARY KEY,
                                        Indicator_ID smallint NOT NULL,
                                        Sector_ID smallint NOT NULL,
                                        Country_ID smallint NOT NULL,
                                        Year smallint NOT NULL,
                                        Quarter smallint NOT NULL,
                                        Value_RM_billions float,
                                        Is_percentage bit NOT NULL,
                                        Is_Q2Q bit,
                                        Date_Created datetime,
                                        Created_By smallint NOT NULL,
                                        Date_Modified datetime,
                                        Modified_By,
                                        Is_Active bit NOT NULL,
                                        Is_Delete bit NOT NULL
                                        
                                    ); """

   
    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_GDP_table)

        # create tasks table
       # create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()

# %%
import sqlite3
from sqlite3 import Error
from datetime import date, datetime


# Insert data
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def create_GDP(conn, GDP):
    """
    Create a new project into the  table
    :param conn:
    :param :
    :return:  id
    """
    sql = ''' INSERT INTO GDP(Indicator_ID, Sector_ID, Country_ID, Year, Quarter, Value_RM_billions, Is_percentage, Is_Q2Q, Date_Created, Created_By, Date_Modified, Modified_By, Is_Active, Is_Delete)
              VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, GDP)
    conn.commit()
    return cur.lastrowid





def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        
              
        for year in range(2018, 2021):
            n=1
            for i in range(4, 9):
                GDP = (1, n, 1, year, -1, df1[year][i], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                n+=1
            GDP = (1, n, 1, year, -1, df1[year][3], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
        for year in range(2018, 2021):
            n=1
            for i in range(28, 33):
                GDP = (1, n, 1, year, -1, df1[year][i], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                n+=1
            GDP = (1, n, 1, year, -1, df1[year][27], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
                
            

            
            
            
            
            

if __name__ == '__main__':
    main()

# %% [markdown]
# Push data into SQL database

# %%
import pyodbc
import os, time
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
 #   cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(index+1)+', @Country_ID= 1 ,@Year='+str(latest_year)+',@Quarter= -1,@Value='+str(row.AnnualGrowthRate)+', @Is_Q2Q=0')


#for year in years:
#    #print('\033[1m','Year:', year,'\033[0m')
#    year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])
#    n=1
#    for i in range(31,36):
        #print(df1.iloc[i].dropna()[-1], df1.iloc[i][year_index],'%')
#        cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(n)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter= -1,@Value='+str(df1.iloc[i][year_index])+', @Is_Q2Q=0')
#        n+=1


print('GDP absolute value')
for year in range(2018, 2021):
    n=1
    for i in range(4, 9):
        print(year, df1['Unnamed: 13'][i], df1[year][i])
        cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(n)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter= -1,@Value_RM_billions='+str(df1[year][i])+', @Is_percentage = 0, @Is_Q2Q=0')
        n+=1
    cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(n)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter= -1,@Value_RM_billions='+str(df1[year][3])+', @Is_percentage = 0, @Is_Q2Q=0')


print('GDP growth')
for year in range(2018, 2021):
    n=1
    for i in range(28, 33):
        print(year, df1['Unnamed: 13'][i], df1[year][i])
        cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(n)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter= -1,@Value_RM_billions='+str(df1[year][i])+', @Is_percentage = 1, @Is_Q2Q=0')
        n+=1
    cursor.execute('[dbo].[SP_ANNUALGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(n)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter= -1,@Value_RM_billions='+str(df1[year][27])+', @Is_percentage = 1, @Is_Q2Q=0')
    print(year, "Total", df1[year][27])






cnxn.commit()
cursor.close()
# Out:
# GDP absolute value
# 2018 Agriculture 99.6
# 2018 Mining and quarrying 103.6
# 2018 Manufacturing 304.8
# 2018 Construction 66.2
# 2018 Services
#  773.0
# 2019 Agriculture 101.6
# 2019 Mining and quarrying 102.9
# 2019 Manufacturing 316.3
# 2019 Construction 66.5
# 2019 Services
#  820.9
# 2020 Agriculture 99.4
# 2020 Mining and quarrying 92.0
# 2020 Manufacturing 307.9
# 2020 Construction 53.6
# 2020 Services
#  775.7
# GDP growth
# 2018 Agriculture 0.1
# 2018 Mining and quarrying -2.2
# 2018 Manufacturing 5.0
# 2018 Construction 4.2
# 2018 Services 6.9
# 2018 Total 4.8
# 2019 Agriculture 2.0
# 2019 Mining and quarrying -0.6
# 2019 Manufacturing 3.8
# 2019 Construction 0.4
# 2019 Services 6.2
# 2019 Total 4.4
# 2020 Agriculture -2.2
# 2020 Mining and quarrying -10.6
# 2020 Manufacturing -2.6
# 2020 Construction -19.4
# 2020 Services -5.5
# 2020 Total -5.6

# %%
"""
for year in years:
    print('\033[1m','Year:', year,'\033[0m')
    year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])
    n = 1
    for i in range(31,36):
        #print(n)
        print(n, df1.iloc[i].dropna()[-1], df1.iloc[i][year_index],'%', year)
        n +=1
"""
# Out:
# "\nfor year in years:\n    print('\x1b','Year:', year,'\x1b')\n    year_index = df1.columns.get_loc(df1.iloc[2][df1.iloc[2] == year].index[-1])\n    n = 1\n    for i in range(31,36):\n        #print(n)\n        print(n, df1.iloc[i].dropna()[-1], df1.iloc[i][year_index],'%', year)\n        n +=1\n"

# %%
#for index, row in df_gdp.iterrows():
 #   print(index, list(islice(cycle(range(1,6)), len(df_gdp)))[index])
    #print(index)

# %%
#today.strftime('%Y/%m/%d')

# %%
#datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx"))
