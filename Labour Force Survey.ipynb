# %%
import pandas as pd

# %%
df = pd.ExcelFile('Publication Table LFR December 2021.xlsx')

# %%
df.sheet_names
# Out:
# ['Table A',
#  'Table B',
#  'Table B1',
#  'Table B2-B3',
#  'Table C',
#  'Table D',
#  'Table E',
#  "Table E_cont'd",
#  'Table F',
#  'Table G',
#  'Sheet13']

# %%
df.sheet_names[0]
# Out:
# 'Table A'

# %%
#df.parse('Table A')

# %%
#df.parse('Table A').head()

# %%
df.parse('Table C', header = 3).head(30)
# Out:
#    Time Series  Labour\nForce   Employed  Unemployed  Outside Labour Force  \
# 0         2010            NaN        NaN         NaN                   NaN
# 1      January      12367.891  11931.152     436.739              6927.510
# 2     February      12059.800  11632.300     427.400              7225.100
# 3        March      12324.200  11895.900     428.300              6993.000
# 4        April      12512.010  12133.505     378.505              6894.505
# 5          May      12197.600  11798.900     398.700              7186.000
# 6         June      12331.800  11882.200     449.600              7065.000
# 7         July      12516.196  12099.494     416.702              6900.457
# 8       August      12320.900  11936.500     384.300              7157.900
# 9    September      12289.900  11912.100     377.800              7194.400
# 10     October      12689.500  12342.600     346.800              6846.700
# ...

# %%
df.parse('Table C', header = 3).tail(60)
# Out:
#     Time Series  Labour\nForce   Employed  Unemployed  Outside Labour Force  \
# 96          May      14961.900  14454.400     507.500              7120.800
# 97         June      15027.600  14519.900     507.700              7141.100
# 98         July      15016.400  14497.400     519.000              7150.400
# 99       August      15030.200  14513.400     516.900              7138.400
# 100   September      15058.800  14544.300     514.500              7122.100
# 101     October      15090.400  14581.700     508.800              7117.700
# 102    November      15084.000  14578.900     505.100              7121.400
# 103    December      15145.900  14640.100     505.800              7084.100
# 104        2018            NaN        NaN         NaN                   NaN
# 105     January      15187.000  14670.500     516.500              7074.800
# 106    February      15230.000  14721.500     508.500              7112.300
# ...

# %%
df1= df.parse('Table C',header = 3)
df1.head()
# Out:
#   Time Series  Labour\nForce   Employed  Unemployed  Outside Labour Force  \
# 0        2010            NaN        NaN         NaN                   NaN
# 1     January      12367.891  11931.152     436.739              6927.510
# 2    February      12059.800  11632.300     427.400              7225.100
# 3       March      12324.200  11895.900     428.300              6993.000
# 4       April      12512.010  12133.505     378.505              6894.505
#
#    Labour Force Participation Rate  Employment to Population Ratio  \
# 0                              NaN                             NaN
# 1                            64.10                           61.83
# 2                            62.53                           60.32
# 3                            63.80                           61.58
# 4                            64.47                           62.52
#
#    Unemployment Rate  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
df1.tail()

# %%
print(df1['Time Series'][117])
for i in range(118, 130):
    print(df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/3091752856.py in <module>
# ----> 1 print(df1['Time Series'][117])
#       2 for i in range(118, 130):
#       3     print(df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
#
# NameError: name 'df1' is not defined

# %%
print(df1['Time Series'][130])
for i in range(131, 143):
    print(df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/740120719.py in <module>
# ----> 1 print(df1['Time Series'][130])
#       2 for i in range(131, 143):
#       3     print(df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
#
# NameError: name 'df1' is not defined

# %%
print(df1['Time Series'][143])
for i in range(144, 156):
    print(monthToNum(df1['Time Series'][i]), int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/2989124731.py in <module>
# ----> 1 print(df1['Time Series'][143])
#       2 for i in range(144, 156):
#       3     print(monthToNum(df1['Time Series'][i]), int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
#
# NameError: name 'df1' is not defined

# %%
row = 105
year_index = row -1

for i in range(row, row+12):
    print(df1['Time Series'][year_index], df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])

row +=13
year_index = row -1

for i in range(row, row+12):
    print(df1['Time Series'][year_index], df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/2006625112.py in <module>
#       3
#       4 for i in range(row, row+12):
# ----> 5     print(df1['Time Series'][year_index], df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])
#       6
#       7 row +=13
#
# NameError: name 'df1' is not defined

# %%
df1.iloc[-1, 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/1167320823.py in <module>
# ----> 1 df1.iloc[-1, 0]
#
# NameError: name 'df1' is not defined

# %%
df1['Unemployment Rate']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/3956804550.py in <module>
# ----> 1 df1['Unemployment Rate']
#
# NameError: name 'df1' is not defined

# %%
#df2= df.parse('Table B',header = 3)
#df2.head()

# %%
#df2.tail()

# %%
#len(df1)

# %%
#df1['Unemployment Rate'].iloc[-1]

# %%
#int(df2['Unemployed'].iloc[-1]*1000)

# %%
#df1['Time Series']

# %%
latest_year = pd.to_numeric(df1['Time Series'], errors = 'coerce').dropna().astype(int).iloc[-1]
latest_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/1015746098.py in <module>
# ----> 1 latest_year = pd.to_numeric(df1['Time Series'], errors = 'coerce').dropna().astype(int).iloc[-1]
#       2 latest_year
#
# NameError: name 'df1' is not defined

# %%
#df1['Time Series']

# %%
#latest_month = list(filter(lambda x: isinstance(x, str), df1['Time Series']))[-1]
#latest_month

# %%
#df1['Time Series'][df1['Time Series'].apply(lambda x: isinstance(x, str))].iloc[-1]

# %%
"""
from datetime import date, datetime

latest_month = list(filter(lambda x: isinstance(x, str), df1['Time Series']))[-1]

latest_month = datetime.strptime(latest_month, '%B').month

latest_month

"""
# Out:
# 10

# %%
print('Unemployment rate for the latest month is', df1['Unemployment Rate'].iloc[-1],'%')
# Out:
# Unemployment rate for the latest month is 4.3 %

# %%
print('Unemployed figure for the latest month is',int(df1['Unemployed'].iloc[-1]*1000))
# Out:
# Unemployed figure for the latest month is 705000

# %%
"""
import pyodbc

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_cpi.iterrows():
cursor.execute("INSERT INTO LabourForceSurvey (Unemployment_rate, Unemployed_figure) values(?,?)",
               df1['Unemployment Rate'].iloc[-1], int(df1['Unemployed'].iloc[-1]*1000))

cnxn.commit()
cursor.close()
"""
# Out:
# '\nimport pyodbc\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_cpi.iterrows():\ncursor.execute("INSERT INTO LabourForceSurvey (Unemployment_rate, Unemployed_figure) values(?,?)",\n               df1[\'Unemployment Rate\'].iloc[-1], int(df1[\'Unemployed\'].iloc[-1]*1000))\n\ncnxn.commit()\ncursor.close()\n'

# %%
"""
import pyodbc
import os, time
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_cpi.iterrows():
cursor.execute("INSERT INTO Economy.LabourForce (Indicator_ID,Country_ID, Year, Month, Unemployment_rate, Unemployed_figure, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?)",
               4, 1, int(latest_year), latest_month, df1['Unemployment Rate'].iloc[-1], int(df1['Unemployed'].iloc[-1]*1000), datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)

cnxn.commit()
cursor.close()

"""
# Out:
# '\nimport pyodbc\nimport os, time\nfrom datetime import date, datetime\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_cpi.iterrows():\ncursor.execute("INSERT INTO Economy.LabourForce (Indicator_ID,Country_ID, Year, Month, Unemployment_rate, Unemployed_figure, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?)",\n               4, 1, int(latest_year), latest_month, df1[\'Unemployment Rate\'].iloc[-1], int(df1[\'Unemployed\'].iloc[-1]*1000), datetime.now().strftime(\'%Y/%m/%d %H:%M:%S\'),1, datetime.now().strftime(\'%Y/%m/%d %H:%M:%S\'),1,1,0)\n\ncnxn.commit()\ncursor.close()\n\n'

# %%
str(latest_year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23540/2001241145.py in <module>
# ----> 1 str(latest_year)
#
# NameError: name 'latest_year' is not defined

# %%
def monthToNum(Month):
    return {
            'January': 1,
            'February': 2,
            'March': 3,
            'April': 4,
            'May': 5,
            'June': 6,
            'July': 7,
            'August': 8,
            'August ': 8,
            'September': 9, 
            'October': 10,
            'November': 11,
            'December': 12
    }[Month]

# %% [markdown]
# Push data to SQLite database

# %%
import sqlite3
from sqlite3 import Error

#Create table

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    sql_create_lf_table = """ CREATE TABLE IF NOT EXISTS LabourForce (
                                        ID INTEGER PRIMARY KEY,
                                        Indicator_ID smallint NOT NULL,
                                        Country_ID smallint NOT NULL,
                                        Year smallint NOT NULL,
                                        Month smallint NOT NULL,
                                        Unemployment_rate float NOT NULL,
                                        Unemployed_figure int NOT NULL,
                                        Date_Created datetime,
                                        Created_By smallint NOT NULL,
                                        Date_Modified datetime,
                                        Modified_By,
                                        Is_Active bit NOT NULL,
                                        Is_Delete bit NOT NULL
                                        
                                    ); """

   
    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_lf_table)

        # create tasks table
       # create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()

# %%
import sqlite3
from sqlite3 import Error
from datetime import date, datetime


# Insert data
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def create_LF(conn, LF):
    """
    Create a new project into the  table
    :param conn:
    :param :
    :return:  id
    """
    sql = ''' INSERT INTO LabourForce(Indicator_ID, Country_ID, Year, Month, Unemployment_rate, Unemployed_figure, Date_Created, Created_By, Date_Modified, Modified_By, Is_Active, Is_Delete)
              VALUES(?,?,?,?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, LF)
    conn.commit()
    return cur.lastrowid





def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        
        row = 105
        year_index = row -1
        
        for i in range(row, row+12):
            LF = (4, 1, df1['Time Series'][year_index], monthToNum(df1['Time Series'][i]), df1['Unemployment Rate'][i], int(df1['Unemployed'][i]*1000), '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_LF(conn, LF)
            #cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
            
        row +=13
        year_index = row -1
        
        for i in range(row, row+12):
            LF = (4, 1, df1['Time Series'][year_index], monthToNum(df1['Time Series'][i]), df1['Unemployment Rate'][i], int(df1['Unemployed'][i]*1000), '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_LF(conn, LF)
          #  cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
            
        row +=13
        year_index = row -1
        
        for i in range(row, row+12):
            LF = (4, 1, df1['Time Series'][year_index], monthToNum(df1['Time Series'][i]), df1['Unemployment Rate'][i], int(df1['Unemployed'][i]*1000), '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_LF(conn, LF)
           # cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
            
        row +=13
        year_index = row -1
        
        for i in range(row, row+12):
            LF = (4, 1, df1['Time Series'][year_index], monthToNum(df1['Time Series'][i]), df1['Unemployment Rate'][i], int(df1['Unemployed'][i]*1000), '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_LF(conn, LF)
           # cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
 
        
       

            
            
            
            

if __name__ == '__main__':
    main()

# %% [markdown]
# Push data to SQL server

# %%
import pyodbc
import os, time
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_cpi.iterrows():
#cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(latest_year)+',@Month='+str(latest_month)+',@Unemployment_Rate='+str(df1['Unemployment Rate'].iloc[-1])+',@Unemployment_Figure='+str(int(df1['Unemployed'].iloc[-1]*1000)))

row = 105
year_index = row -1

for i in range(row, row+12):
    cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))

   # print(df1['Time Series'][year_index], df1['Time Series'][i], int(df1['Unemployed'][i]*1000), df1['Unemployment Rate'][i])

row +=13
year_index = row -1

for i in range(row, row+12):
    cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
    

row +=13
year_index = row -1

for i in range(row, row+12):
    cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
    
row +=13
year_index = row -1

for i in range(row, row+12):
    cursor.execute('[dbo].[SP_LABORFORCE_I_220114] @Indicator_ID = 4 ,@Country_ID= 1 ,@Year='+str(df1['Time Series'][year_index])+',@Month='+str(monthToNum (df1['Time Series'][i]))+',@Unemployment_Rate='+str(df1['Unemployment Rate'][i])+',@Unemployment_Figure='+str( int(df1['Unemployed'][i]*1000)))
    

    
cnxn.commit()
cursor.close()

# %%
#print('aaaa'+'aaaaa')

# %%
"""
import pyodbc
import os, time
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

#for index, row in df_annual_growth_rate.iterrows():
 #   cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
  #                  1,index+1,1, int(latest_year), latest_quarter, row.Rate, 0, datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx")),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
    
#for index, row in df_q2q_growth_rate.iterrows():



cursor.execute("INSERT INTO Economy.LabourForce (Indicator_ID,Country_ID, Year, Month, Unemployment_rate, Unemployed_figure, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?)",
                 4,1, int(latest_year), latest_month, df1['Unemployment Rate'].iloc[-1], int(df1['Unemployed'].iloc[-1]*1000, datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx")),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)

               
               
#cnxn.commit()    
               
cnxn.commit()
cursor.close()
"""
# Out:
# '\nimport pyodbc\nimport os, time\nfrom datetime import date, datetime\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_gdp.iterrows():\n   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n    #                index+1, row.AnnualGrowthRate)\n\n#for index, row in df_annual_growth_rate.iterrows():\n #   cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n  #                  1,index+1,1, int(latest_year), latest_quarter, row.Rate, 0, datetim
# ...
