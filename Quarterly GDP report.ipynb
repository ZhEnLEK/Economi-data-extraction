# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
def RomanToArab(quarter):
    return {
            'I': 1,
            'II': 2,
            'III': 3,
            'IV': 4
            
    }[quarter]

# %%
#from datetime import date

# %%
#date.today().year

# %%
df = pd.ExcelFile('GDP Q3 2021 Tables.xlsx')

# %%
#df = pd.ExcelFile('GDP Q2 2021 Tables.xlsx')

# %%
#df.sheet_names

# %%
#df.sheet_names[0]

# %%
#df.parse('Data Makro').head(50)

# %%
df1 = df.parse('Data Makro')
df1.head(50)
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0          NaN  MALAYSIA:                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# 5          NaN        NaN             KDNK pada harga malar 2015 (RM bilion)
# 6          NaN        NaN                                          Pertanian
# 7          NaN        NaN                       Perlombongan dan pengkuarian
# 8          NaN        NaN                                          Pembuatan
# 9          NaN        NaN                                          Pembinaan
# 10         NaN        NaN                                       Perkhidmatan
# ...

# %%
pd.to_numeric(df1.iloc[6], errors = 'coerce').dropna()[-1]
# Out:
# 27.5

# %%
len(df1.iloc[6].dropna())
# Out:
# 35

# %%
df1.iloc[6].dropna()
# Out:
# Unnamed: 2          Pertanian
# Unnamed: 4                 98
# Unnamed: 5               94.0
# Unnamed: 6               99.5
# Unnamed: 7               99.6
# Unnamed: 8              101.6
# Unnamed: 9               99.4
# Unnamed: 10              21.7
# Unnamed: 11                24
# Unnamed: 12              27.7
# Unnamed: 13              24.2
# Unnamed: 15              21.2
# Unnamed: 16              22.6
# Unnamed: 17              26.4
# Unnamed: 18              23.7
# Unnamed: 20              22.6
# Unnamed: 21              23.6
# Unnamed: 22              27.3
# Unnamed: 23                26
# Unnamed: 25              23.3
# Unnamed: 26              23.3
# Unnamed: 27              27.1
# Unnamed: 28                26
# Unnamed: 30              24.7
# Unnamed: 31              24.3
# Unnamed: 32              28.1
# Unnamed: 33              24.5
# Unnamed: 35              22.6
# Unnamed: 36              24.5
# Unnamed: 37                28
# Unnamed: 38              24.3
# ...

# %%
#100*(df1.iloc[6].dropna()[-2] - df1.iloc[6].dropna()[-3])/df1.iloc[6].dropna()[-3]

# %%
#index = -2
#100*(df1.iloc[6].dropna()[index] - df1.iloc[6].dropna()[index-1])/df1.iloc[6].dropna()[index-1]

# %%
#index -=1
#index

# %%
column = 12

df1.iloc[3].dropna()[column]
# Out:
# 'I'

# %%
column = 12
#df1.iloc[3].dropna()[column]
RomanToArab(df1.iloc[3].dropna()[column])
# Out:
# 1

# %%
column
# Out:
# 12

# %%
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
column = 25
year = 2018
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1
    print(year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], "Total", j)
    j=1
    for i in range(13, 18):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1    
    print(year, RomanToArab(df1.iloc[3][c]), df1.iloc[12][c], "Total", j)
    column+=1
 

column+=1
year +=1
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1
    j=1
    for i in range(13, 18):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1  
    column+=1

    
column+=1
year +=1
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1
    j=1
    for i in range(13, 18):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1    
    column+=1

column+=1
year +=1
for c in range(column, column+3):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1
   # print(year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], "Total", j)
    j=1
    for i in range(13, 18):
        print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
        j+=1 
    column+=1
# Out:
# 2018 1 23.3    Agriculture 1
# 2018 1 26.2    Mining and quarrying 2
# 2018 1 72.6    Manufacturing 3
# 2018 1 16.6    Construction 4
# 2018 1 183.4    Services 5
# 2018 1 327.1 Total 6
# 2018 1 3.1    Agriculture 1
# 2018 1 -2.4    Mining and quarrying 2
# 2018 1 5.2    Manufacturing 3
# 2018 1 4.9    Construction 4
# 2018 1 6.6    Services 5
# 2018 1 5.3 Total 6
# 2018 2 23.3    Agriculture 1
# 2018 2 25.9    Mining and quarrying 2
# 2018 2 75.7    Manufacturing 3
# 2018 2 16    Construction 4
# 2018 2 188.3    Services 5
# 2018 2 333.4 Total 6
# 2018 2 -1.5    Agriculture 1
# 2018 2 -1.3    Mining and quarrying 2
# 2018 2 4.9    Manufacturing 3
# 2018 2 4.8    Construction 4
# 2018 2 6.6    Services 5
# 2018 2 4.8 Total 6
# 2018 3 27.1    Agriculture 1
# 2018 3 24.2    Mining and quarrying 2
# 2018 3 77.1    Manufacturing 3
# 2018 3 17.2    Construction 4
# 2018 3 196.9    Services 5
# 2018 3 345.7 Total 6
# 2018 3 -0.7    Agriculture 1
# 2018 3 -5    Mining and quarrying 2
# ...

# %%
column =43
year = 2021

# %%
index = -2
column -= 1 
#year -=1
for c in range(column, column-3, -1):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], df1.iloc[i][43], j)
       # index -=1
        j+=1
    print( year , RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], "Total", j)
    j=1
    index -=1
    #for i in range(13, 18):
    #    print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
    #    j+=1    
    column-=1

column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], df1.iloc[i][43], j)
       # index -=1
        j+=1
    j=1
    index -=1
    #for i in range(13, 18):
    #    print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
    #    j+=1    
    column-=1
    
column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], df1.iloc[i][43], j)
       # index -=1
        j+=1
    j=1
    index -=1
    #for i in range(13, 18):
    #    print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
    #    j+=1    
    column-=1
    
column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        print( year , RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], df1.iloc[i][43], j)
       # index -=1
        j+=1
    index -=1
    #for i in range(13, 18):
    #    print( year , RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], df1.iloc[i][43], j)
    #    j+=1    
    column-=1
# Out:
# 2021 3 14.10788381742738    Agriculture 1
# 2021 3 -12.916666666666671    Mining and quarrying 2
# 2021 3 0.24479804161567054    Manufacturing 3
# 2021 3 -6.34920634920634    Construction 4
# 2021 3 0.21052631578947667    Services 5
# 2021 3 -0.20802377414561327 Total 6
# 2021 2 6.63716814159292    Agriculture 1
# 2021 2 -0.41493775933610544    Mining and quarrying 2
# 2021 2 -0.12224938875304929    Manufacturing 3
# 2021 2 -8.695652173913052    Construction 4
# 2021 2 -3.4062023385866746    Services 5
# 2021 2 -1.8950437317784257 Total 6
# 2021 1 -6.9958847736625485    Agriculture 1
# 2021 1 1.2605042016806751    Mining and quarrying 2
# 2021 1 -2.850356294536824    Manufacturing 3
# 2021 1 -3.4965034965034962    Construction 4
# 2021 1 -4.837929366231253    Services 5
# 2021 1 -4.163174070969538 Total 6
# 2020 4 -13.214285714285712    Agriculture 1
# 2020 4 9.677419354838717    Mining and quarrying 2
# 2020 4 2.060606060606064    Manufacturing 3
# ...

# %%
for c in range(column, column-3, -1):
    print(c)
# Out:
# 24
# 23
# 22

# %%
for year in range(2018, 2022):
    print(year)
    df1.iloc[6]
# Out:
# 2018
# 2019
# 2020
# 2021

# %%
df1['Unnamed: 15'][2]
# Out:
# 2016

# %%
df1.iloc[2][15]
# Out:
# 2016

# %%
df1.iloc[2].dropna().tail(6)
# Out:
# Unnamed: 15    2016
# Unnamed: 20    2017
# Unnamed: 25    2018
# Unnamed: 30    2019
# Unnamed: 35    2020
# Unnamed: 40    2021
# Name: 2, dtype: object

# %%
df1.iloc[2].dropna().tail(6).astype(int)
# Out:
# Unnamed: 15    2016
# Unnamed: 20    2017
# Unnamed: 25    2018
# Unnamed: 30    2019
# Unnamed: 35    2020
# Unnamed: 40    2021
# Name: 2, dtype: int32

# %%
df1.iloc[3].dropna()
# Out:
# Unnamed: 10      I
# Unnamed: 11     II
# Unnamed: 12    III
# Unnamed: 13     IV
# Unnamed: 15      I
# Unnamed: 16     II
# Unnamed: 17    III
# Unnamed: 18     IV
# Unnamed: 20      I
# Unnamed: 21     II
# Unnamed: 22    III
# Unnamed: 23     IV
# Unnamed: 25      I
# Unnamed: 26     II
# Unnamed: 27    III
# Unnamed: 28     IV
# Unnamed: 30      I
# Unnamed: 31     II
# Unnamed: 32    III
# Unnamed: 33     IV
# Unnamed: 35      I
# Unnamed: 36     II
# Unnamed: 37    III
# Unnamed: 38     IV
# Unnamed: 40      I
# Unnamed: 41     II
# Unnamed: 42    III
# Name: 3, dtype: object

# %%
df1.iloc[5].dropna()
# Out:
# Unnamed: 2       KDNK pada harga malar 2015 (RM bilion)
# Unnamed: 4                                         1177
# Unnamed: 5                                       1229.3
# Unnamed: 6                                       1300.8
# Unnamed: 7                                       1363.8
# Unnamed: 8                                       1424.3
# Unnamed: 9                                       1343.9
# Unnamed: 10                                       282.3
# Unnamed: 11                                         289
# Unnamed: 12                                         298
# Unnamed: 13                                       307.7
# Unnamed: 15                                       294.3
# Unnamed: 16                                         301
# Unnamed: 17                                       311.5
# Unnamed: 18                                       322.5
# Unnamed: 20                                       310.7
# Unnamed: 21                                       318.2
# ...

# %%
"""
def RomanToArab(quarter):
    return {
            'I': 1,
            'II': 2,
            'III': 3,
            'IV': 4
            
    }[quarter]
    
    
"""
# Out:
# "\ndef RomanToArab(quarter):\n    return {\n            'I': 1,\n            'II': 2,\n            'III': 3,\n            'IV': 4\n            \n    }[quarter]\n    \n    \n"

# %%
#df1['Unnamed: 42'].drop([3]).dropna() - df1['Unnamed: 41'].drop([3]).dropna()

# %%
#df1.iloc[2].dropna()

# %%
#pd.to_numeric(df1.iloc[2], errors= 'coerce').dropna().astype(int)

# %%
#min(pd.to_numeric(df1.iloc[2], errors= 'coerce').dropna().astype(int))

# %%
#start_year = 2016
#start_year

# %%
index_start_year = df1.columns.get_loc(df1.iloc[2][df1.iloc[2]==start_year].index[-1])
index_start_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2252/2853173031.py in <module>
# ----> 1 index_start_year = df1.columns.get_loc(df1.iloc[2][df1.iloc[2]==start_year].index[-1])
#       2 index_start_year
#
# NameError: name 'start_year' is not defined

# %%
df1.columns.get_loc(df1.iloc[2][df1.iloc[2]==latest_year].index[-1])

# %%
#df1.iloc[2].dropna()

# %%
latest_year = df1.iloc[2].dropna()[-1]
latest_year
# Out:
# 2021

# %%
#df1.iloc[2].dropna()[6]

# %%
#years = df2.iloc[2].dropna()

# %%
#years

# %%
#years[years.apply(lambda x: isinstance(x, int))]

# %%
#max(years[years.apply(lambda x: isinstance(x, int))])

# %%
df1.iloc[3].dropna()[0]
# Out:
# 'I'

# %%
df1.iloc[3][index_start_year]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/1468822881.py in <module>
# ----> 1 df1.iloc[3][index_start_year]
#
# NameError: name 'index_start_year' is not defined

# %%
df1.iloc[3]
# Out:
# Unnamed: 0     NaN
# Unnamed: 1     NaN
# Unnamed: 2     NaN
# Unnamed: 3     NaN
# Unnamed: 4     NaN
# Unnamed: 5     NaN
# Unnamed: 6     NaN
# Unnamed: 7     NaN
# Unnamed: 8     NaN
# Unnamed: 9     NaN
# Unnamed: 10      I
# Unnamed: 11     II
# Unnamed: 12    III
# Unnamed: 13     IV
# Unnamed: 14    NaN
# Unnamed: 15      I
# Unnamed: 16     II
# Unnamed: 17    III
# Unnamed: 18     IV
# Unnamed: 19    NaN
# Unnamed: 20      I
# Unnamed: 21     II
# Unnamed: 22    III
# Unnamed: 23     IV
# Unnamed: 24    NaN
# Unnamed: 25      I
# Unnamed: 26     II
# Unnamed: 27    III
# Unnamed: 28     IV
# Unnamed: 29    NaN
# Unnamed: 30      I
# Unnamed: 31     II
# Unnamed: 32    III
# Unnamed: 33     IV
# Unnamed: 34    NaN
# Unnamed: 35      I
# Unnamed: 36     II
# Unnamed: 37    III
# Unnamed: 38     IV
# Unnamed: 39    NaN
# Unnamed: 40      I
# Unnamed: 41     II
# Unnamed: 42    III
# Unnamed: 43    NaN
# Unnamed: 44    NaN
# Unnamed: 45    NaN
# Unnamed: 46    NaN
# ...

# %%
#import roman

latest_quarter = df1.iloc[3].dropna()[-1]
#latest_quarter=roman.fromRoman(latest_quarter)
latest_quarter
# Out:
# 'III'

# %%
#pip install roman

# %%
#df1.iloc[3].dropna()[-1]

# %%
previous_quarter = df1.iloc[3].dropna()[-2]
previous_quarter
# Out:
# 'II'

# %%
#df1.iloc[3][df1.iloc[3] == latest_quarter].index

# %%
#df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1]

# %%
#df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1])

# %%
#df1.iloc[3][df1.iloc[3] == previous_quarter].index

# %%
index_latest_quarter =  df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1])

# %%
index_latest_quarter
# Out:
# 42

# %%
index_previous_quarter = df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == previous_quarter].index[-1])

# %%
index_previous_quarter
# Out:
# 41

# %%
df1.iloc[13].dropna()[-1]
# Out:
# '   Agriculture'

# %%
df1.iloc[13][index_latest_quarter-3]
# Out:
# nan

# %%
print('\033[1m','Latest year:',latest_year,'   Latest quarter:',latest_quarter,'\033[0m')

print('\033[1m','Annual growth rate of latest quarterly GDP (subsectors):','\033[0m')
growth_rate = []

for i in range(13,18):
    print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter],'%')
    growth_rate.append([df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter]])
    
#for i in range(20,27):
 #   print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter])
# Out:
#  Latest year: 2021    Latest quarter: III
#  Annual growth rate of latest quarterly GDP (subsectors):
#    Agriculture -1.9 %
#    Mining and quarrying -3.6 %
#    Manufacturing -0.8 %
#    Construction -20.6 %
#    Services -4.9 %

# %%
df_annual_growth_rate = pd.DataFrame(growth_rate, columns = ['Sector', 'Rate'])
df_annual_growth_rate
# Out:
#                     Sector  Rate
# 0              Agriculture  -1.9
# 1     Mining and quarrying  -3.6
# 2            Manufacturing  -0.8
# 3             Construction -20.6
# 4                 Services  -4.9

# %%
#df1.iloc[6][index_previous_quarter] - df1.iloc[6][index_latest_quarter]

# %%
#((df1.iloc[6][index_latest_quarter] - df1.iloc[6][index_previous_quarter])/df1.iloc[6][index_previous_quarter])*100

# %%
print('\033[1m','Latest year:',latest_year,'   Latest quarter:',latest_quarter,'\033[0m')

print('\033[1m','Latest quarter to quarter comparison of GDP growth rate:','\033[0m')

q2q_growth_rate = []

for i in range(6,11):
    print(df1.iloc[i].dropna()[-1],
          ((df1.iloc[i][index_latest_quarter] - df1.iloc[i][index_previous_quarter])/df1.iloc[i][index_previous_quarter])*100,
         "%")
    q2q_growth_rate.append([df1.iloc[i].dropna()[-1],
          ((df1.iloc[i][index_latest_quarter] - df1.iloc[i][index_previous_quarter])/df1.iloc[i][index_previous_quarter])*100])
    #print(df1.iloc[-i])
# Out:
#  Latest year: 2021    Latest quarter: III
#  Latest quarter to quarter comparison of GDP growth rate:
#    Agriculture 14.10788381742738 %
#    Mining and quarrying -12.916666666666673 %
#    Manufacturing 0.24479804161567056 %
#    Construction -6.349206349206341 %
#    Services 0.21052631578947667 %

# %%
df_q2q_growth_rate = pd.DataFrame(q2q_growth_rate, columns = ['Sector', 'Rate'])
df_q2q_growth_rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/3933230594.py in <module>
# ----> 1 df_q2q_growth_rate = pd.DataFrame(q2q_growth_rate, columns = ['Sector', 'Rate'])
#       2 df_q2q_growth_rate
#
# NameError: name 'q2q_growth_rate' is not defined

# %%
"""
import pyodbc
import os, time
import roman
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

for index, row in df_annual_growth_rate.iterrows():
    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
                    2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 0, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
    
for index, row in df_q2q_growth_rate.iterrows():
    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
                    2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
cnxn.commit()
cursor.close()

"""
# Out:
# '\nimport pyodbc\nimport os, time\nimport roman\nfrom datetime import date, datetime\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_gdp.iterrows():\n   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n    #                index+1, row.AnnualGrowthRate)\n\nfor index, row in df_annual_growth_rate.iterrows():\n    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n                    2,index+1,1, int(latest_year), roman.fromRoman(latest_qu
# ...

# %% [markdown]
# Push data into SQLite database

# %%
import sqlite3
from sqlite3 import Error

#Create table

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    sql_create_GDP_table = """ CREATE TABLE IF NOT EXISTS GDP (
                                        ID smallint PRIMARY KEY,
                                        Indicator_ID smallint NOT NULL,
                                        Sector_ID smallint NOT NULL,
                                        Country_ID smallint NOT NULL,
                                        Year smallint NOT NULL,
                                        Quarter smallint NOT NULL,
                                        Value_RM_billions float,
                                        Is_percentage bit NOT NULL,
                                        Is_Q2Q bit,
                                        Date_Created datetime,
                                        Created_By smallint NOT NULL,
                                        Date_Modified datetime,
                                        Modified_By,
                                        Is_Active bit NOT NULL,
                                        Is_Delete bit NOT NULL
                                        
                                    ); """

   
    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_GDP_table)

        # create tasks table
       # create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()

# %%
import sqlite3
from sqlite3 import Error
from datetime import date, datetime


# Insert data
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def create_GDP(conn, GDP):
    """
    Create a new project into the  table
    :param conn:
    :param :
    :return:  id
    """
    sql = ''' INSERT INTO GDP(Indicator_ID, Sector_ID, Country_ID, Year, Quarter, Value_RM_billions, Is_percentage, Is_Q2Q, Date_Created, Created_By, Date_Modified, Modified_By, Is_Active, Is_Delete)
              VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, GDP)
    conn.commit()
    return cur.lastrowid





def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        column = 25
        year = 2018
        for c in range(column, column+4):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            j=1
            for i in range(13, 18):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1    
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[12][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            column+=1
         
        column +=1
        year +=1
        for c in range(column, column+4):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            j=1
            for i in range(13, 18):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1    
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[12][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            column+=1
            
        column +=1
        year +=1
        for c in range(column, column+4):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            j=1
            for i in range(13, 18):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1    
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[12][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            column+=1
            
        column +=1
        year +=1
        for c in range(column, column+3):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[5][c], 0, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            j=1
            for i in range(13, 18):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[i][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1    
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), df1.iloc[12][c], 1, 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            column+=1
            
        index = -2
        column -= 1 
        
        for c in range(column, column-3, -1):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            index -=1
            column-=1
        
        column -= 1 
        year -=1
        
        for c in range(column, column-4, -1):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            index -=1
            column-=1
            
        column -= 1 
        year -=1
        
        for c in range(column, column-4, -1):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            index -=1
            column-=1

        column -= 1 
        year -=1
        
        for c in range(column, column-4, -1):
            j=1
            for i in range(6, 11):
                GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_GDP(conn, GDP)
                j+=1
            GDP = (1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_GDP(conn, GDP)
            
            index -=1
            column-=1
           
   
        
            
            
            
            

if __name__ == '__main__':
    main()

# %%
column = 42
index = -2
column -= 1 
        
for c in range(column, column-3, -1):
    j=1
    for i in range(6, 11):
        print(1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                #create_GDP(conn, GDP)
        j+=1
    print(1, j, 1, year, RomanToArab(df1.iloc[3][c]), 100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1], 1, 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
          #  create_GDP(conn, GDP)
# Out:
# 1 1 1 2021 2 14.10788381742738 1 1 - 1 2022/04/06 1 1 0
# 1 2 1 2021 2 -12.916666666666671 1 1 - 1 2022/04/06 1 1 0
# 1 3 1 2021 2 0.24479804161567054 1 1 - 1 2022/04/06 1 1 0
# 1 4 1 2021 2 -6.34920634920634 1 1 - 1 2022/04/06 1 1 0
# 1 5 1 2021 2 0.21052631578947667 1 1 - 1 2022/04/06 1 1 0
# 1 6 1 2021 2 -0.20802377414561327 1 1 - 1 2022/04/06 1 1 0
# 1 1 1 2021 1 14.10788381742738 1 1 - 1 2022/04/06 1 1 0
# 1 2 1 2021 1 -12.916666666666671 1 1 - 1 2022/04/06 1 1 0
# 1 3 1 2021 1 0.24479804161567054 1 1 - 1 2022/04/06 1 1 0
# 1 4 1 2021 1 -6.34920634920634 1 1 - 1 2022/04/06 1 1 0
# 1 5 1 2021 1 0.21052631578947667 1 1 - 1 2022/04/06 1 1 0
# 1 6 1 2021 1 -0.20802377414561327 1 1 - 1 2022/04/06 1 1 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8480/773286358.py in <module>
#       6     j=1
#       7     for i in range(6, 11):
# ...

# %%
column
# Out:
# 22

# %%
df1.head(30)
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0          NaN  MALAYSIA:                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# 5          NaN        NaN             KDNK pada harga malar 2015 (RM bilion)
# 6          NaN        NaN                                          Pertanian
# 7          NaN        NaN                       Perlombongan dan pengkuarian
# 8          NaN        NaN                                          Pembuatan
# 9          NaN        NaN                                          Pembinaan
# 10         NaN        NaN                                       Perkhidmatan
# ...

# %% [markdown]
# Push data into SQL database

# %%
import pyodbc
import os, time
import roman
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

#for index, row in df_annual_growth_rate.iterrows():
   # cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #               2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 0, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
    
#for index, row in df_q2q_growth_rate.iterrows():
   # cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)

#for index, row in df_annual_growth_rate.iterrows():
#    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(-1)+' , @Value='+str(df1.iloc[i][column])+', @Is_Q2Q=0')

#for index, row in df_q2q_growth_rate.iterrows():
#    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][column]))+' , @Value='+str(df1.iloc[i][column])+', @Is_Q2Q=0')

    
column = 25
year = 2018
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+', @Is_percentage=0, @Is_Q2Q=0')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[5][c])+', @Is_percentage=0, @Is_Q2Q=0')
   
    j=1
    for i in range(13, 18):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+', @Is_percentage= 0, @Is_Q2Q= 1') #have no idea why the value flip 28/2/2022, hence will flip the value for this query
        j+=1    
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[12][c])+', @Is_percentage= 0, @Is_Q2Q= 1') #have no idea why the value flip 28/2/2022, hence will flip the value for this query
    column+=1
 
column += 1 
year +=1
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+', @Is_percentage=0, @Is_Q2Q=0')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[5][c])+', @Is_percentage=0, @Is_Q2Q=0')

    j=1
    for i in range(13, 18):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+', @Is_percentage=0, @Is_Q2Q=1')
        j+=1    
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[12][c])+', @Is_percentage=0, @Is_Q2Q=1')
   
    column+=1
    
column += 1 
year +=1
for c in range(column, column+4):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+',@Is_percentage=0, @Is_Q2Q=0')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[5][c])+',@Is_percentage=0, @Is_Q2Q=0')

    j=1
    for i in range(13, 18):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+',  @Is_percentage=0, @Is_Q2Q=1')
        j+=1    
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[12][c])+',  @Is_percentage=0, @Is_Q2Q=1')
 
    column+=1
    
column += 1 
year +=1
for c in range(column, column+3):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+', @Is_percentage=0,@Is_Q2Q=0')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[5][c])+', @Is_percentage=0,@Is_Q2Q=0')
   
    j=1
    for i in range(13, 18):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[i][c])+',  @Is_percentage=0, @Is_Q2Q=1')
        j+=1    
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(df1.iloc[12][c])+',  @Is_percentage=0, @Is_Q2Q=1')

    column+=1    
    
    
index = -2
column -= 1 
for c in range(column, column-3, -1):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1])+', @Is_percentage=1, @Is_Q2Q=1')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1])+', @Is_percentage=1, @Is_Q2Q=1')

    index -=1
    column-=1
    
column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1])+', @Is_percentage=1,@Is_Q2Q=1')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1])+', @Is_percentage=1,@Is_Q2Q=1')

    index -=1
    column-=1    

column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1])+', @Is_percentage=1,@Is_Q2Q=1')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1])+', @Is_percentage=1,@Is_Q2Q=1')

    index -=1
    column-=1 
    
column -= 1 
year -=1
for c in range(column, column-4, -1):
    j=1
    for i in range(6, 11):
        cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[i].dropna()[index] - df1.iloc[i].dropna()[index-1])/df1.iloc[i].dropna()[index-1])+', @Is_percentage=1, @Is_Q2Q=1')
        j+=1
    cursor.execute('[dbo].[SP_QUARTERLYGDP_I_220117] @Indicator_ID = 1 , @Sector_ID = '+str(j)+', @Country_ID= 1 ,@Year='+str(year)+',@Quarter='+str(RomanToArab(df1.iloc[3][c]))+' , @Value_RM_billions='+str(100*(df1.iloc[5].dropna()[index] - df1.iloc[5].dropna()[index-1])/df1.iloc[5].dropna()[index-1])+', @Is_percentage=1, @Is_Q2Q=1')

    index -=1
    column-=1 
    
    
cnxn.commit()
cursor.close()
