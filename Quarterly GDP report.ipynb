# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
#from datetime import date

# %%
#date.today().year

# %%
df = pd.ExcelFile('GDP Q3 2021 Tables.xlsx')

# %%
#df = pd.ExcelFile('GDP Q2 2021 Tables.xlsx')

# %%
df.sheet_names
# Out:
# ['Data Makro',
#  'Jadual Ringkasan',
#  '1A-1B',
#  '1C-1D',
#  '2A-2B',
#  '3A-3B',
#  '4A',
#  '4B',
#  '5A',
#  '5B',
#  '6A',
#  '6B',
#  '7A',
#  '7B',
#  '8A',
#  '8B',
#  '9A',
#  '9B',
#  '10A',
#  '10B',
#  '11A',
#  '11B']

# %%
df.sheet_names[0]
# Out:
# 'Data Makro'

# %%
#df.parse('Data Makro').head(50)

# %%
df1 = df.parse('Data Makro')
df1.head(50)
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0          NaN  MALAYSIA:                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# 5          NaN        NaN             KDNK pada harga malar 2015 (RM bilion)
# 6          NaN        NaN                                          Pertanian
# 7          NaN        NaN                       Perlombongan dan pengkuarian
# 8          NaN        NaN                                          Pembuatan
# 9          NaN        NaN                                          Pembinaan
# 10         NaN        NaN                                       Perkhidmatan
# ...

# %%
#df1['Unnamed: 42'].drop([3]).dropna() - df1['Unnamed: 41'].drop([3]).dropna()

# %%
#df1.iloc[2].dropna()

# %%
latest_year = df1.iloc[2].dropna()[-1]
latest_year
# Out:
# 2021

# %%
#years = df2.iloc[2].dropna()

# %%
#years

# %%
#years[years.apply(lambda x: isinstance(x, int))]

# %%
#max(years[years.apply(lambda x: isinstance(x, int))])

# %%
#import roman

latest_quarter = df1.iloc[3].dropna()[-1]
#latest_quarter=roman.fromRoman(latest_quarter)
latest_quarter
# Out:
# 'III'

# %%
#pip install roman

# %%
#df1.iloc[3].dropna()[-1]
# Out:
# 'III'

# %%
#previous_quarter = df1.iloc[3].dropna()[-2]
#previous_quarter
# Out:
# 'II'

# %%
#df1.iloc[3][df1.iloc[3] == latest_quarter].index
# Out:
# Index([], dtype='object')

# %%
#df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1]

# %%
#df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1])

# %%
#df1.iloc[3][df1.iloc[3] == previous_quarter].index

# %%
index_latest_quarter =  df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == latest_quarter].index[-1])

# %%
index_latest_quarter
# Out:
# 42

# %%
index_previous_quarter = df1.columns.get_loc(df1.iloc[3][df1.iloc[3] == previous_quarter].index[-1])

# %%
index_previous_quarter
# Out:
# 41

# %%
df1.iloc[13].dropna()[-1]
# Out:
# '   Agriculture'

# %%
print('\033[1m','Latest year:',latest_year,'   Latest quarter:',latest_quarter,'\033[0m')

print('\033[1m','Annual growth rate of latest quarterly GDP (subsectors):','\033[0m')
growth_rate = []

for i in range(13,18):
    print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter],'%')
    growth_rate.append([df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter]])
    
#for i in range(20,27):
 #   print(df1.iloc[i].dropna()[-1], df1.iloc[i][index_latest_quarter])
# Out:
#  Latest year: 2021    Latest quarter: III
#  Annual growth rate of latest quarterly GDP (subsectors):
#    Agriculture -1.9 %
#    Mining and quarrying -3.6 %
#    Manufacturing -0.8 %
#    Construction -20.6 %
#    Services -4.9 %

# %%
df_annual_growth_rate = pd.DataFrame(growth_rate, columns = ['Sector', 'Rate'])
df_annual_growth_rate
# Out:
#                     Sector  Rate
# 0              Agriculture  -1.9
# 1     Mining and quarrying  -3.6
# 2            Manufacturing  -0.8
# 3             Construction -20.6
# 4                 Services  -4.9

# %%
#df1.iloc[6][index_previous_quarter] - df1.iloc[6][index_latest_quarter]

# %%
#((df1.iloc[6][index_latest_quarter] - df1.iloc[6][index_previous_quarter])/df1.iloc[6][index_previous_quarter])*100

# %%
print('\033[1m','Latest year:',latest_year,'   Latest quarter:',latest_quarter,'\033[0m')

print('\033[1m','Latest quarter to quarter comparison of GDP growth rate:','\033[0m')

q2q_growth_rate = []

for i in range(6,11):
    print(df1.iloc[i].dropna()[-1],
          ((df1.iloc[i][index_latest_quarter] - df1.iloc[i][index_previous_quarter])/df1.iloc[i][index_previous_quarter])*100,
         "%")
    q2q_growth_rate.append([df1.iloc[i].dropna()[-1],
          ((df1.iloc[i][index_latest_quarter] - df1.iloc[i][index_previous_quarter])/df1.iloc[i][index_previous_quarter])*100])
    #print(df1.iloc[-i])
# Out:
#  Latest year: 2021    Latest quarter: III
#  Latest quarter to quarter comparison of GDP growth rate:
#    Agriculture 14.10788381742738 %
#    Mining and quarrying -12.916666666666673 %
#    Manufacturing 0.24479804161567056 %
#    Construction -6.349206349206341 %
#    Services 0.21052631578947667 %

# %%
df_q2q_growth_rate = pd.DataFrame(q2q_growth_rate, columns = ['Sector', 'Rate'])
df_q2q_growth_rate
# Out:
#                     Sector       Rate
# 0              Agriculture  14.107884
# 1     Mining and quarrying -12.916667
# 2            Manufacturing   0.244798
# 3             Construction  -6.349206
# 4                 Services   0.210526

# %%
import pyodbc
import os, time
import roman
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

for index, row in df_annual_growth_rate.iterrows():
    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
                    2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 0, datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx")),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
    
for index, row in df_q2q_growth_rate.iterrows():
    cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
                    2,index+1,1, int(latest_year), roman.fromRoman(latest_quarter), row.Rate, 1, datetime.fromtimestamp(os.path.getctime("Annual GDP 2015-2020 Tables.xlsx")),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
cnxn.commit()
cursor.close()
