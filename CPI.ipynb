# %%
import pandas as pd

# %%
df = pd.ExcelFile('15tab1Msia_Dis21.xlsx')

# %%
df

# %%
df.sheet_names
# Out:
# ['J1_J4',
#  'J5A',
#  'J5B',
#  'J5C',
#  'J5D',
#  'J6',
#  'J7',
#  'J8_J9',
#  'J10',
#  'J11',
#  'J12_J13',
#  'J14',
#  'J15',
#  'J16_J17',
#  'J18',
#  'J19',
#  '4d_J20']

# %%
#df2 = df.parse(2)
#df2.head(20)

# %%
#df2.tail(30)

# %%
#df2.iloc[:,0].dropna()

# %%
#pd.to_numeric(df2.iloc[:,0], errors = 'coerce').dropna().astype(int)

# %%
#df2.iloc[:,1].dropna()

# %%
#df2.iloc[[38]]

# %%
#for i, j in df2.iloc[[38]].iterrows():
 #   print(i, j)

# %%
df.sheet_names[0]
# Out:
# 'J1_J4'

# %%
#df.parse('J1_J4').head(40)

# %%
df1 = df.parse(0)
df1.head(20)
# Out:
#    Jadual 1 - Indeks Harga Pengguna (2010=100), Nombor Indeks Kumpulan Utama dan Perubahan Peratus, Malaysia  \
# 0   Table 1 - Consumer Price Index (2010=100), Ind...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# ...

# %%
latest_year = pd.to_numeric(df.parse(0).iloc[3], errors = 'coerce').dropna().astype(int)[-1]
latest_year
# Out:
# 2021

# %%
pd.to_numeric(df.parse(0).iloc[2], errors = 'coerce').dropna()#.astype(int)
# Out:
# Series([], Name: 2, dtype: float64)

# %%
df.parse(0).iloc[2].dropna()
# Out:
# Unnamed: 1                     I. Nombor Indeks:
# Unnamed: 2                                                   DIS
# Unnamed: 3                                                   NOV
# Unnamed: 4                                                   DIS
# Unnamed: 10    I. Nombor Purata Indeks Kumpulan Utama bagi Te...
# Unnamed: 13                      JAN - DIS 2021 ; JAN - DIS 2020
# Name: 2, dtype: object

# %%
df2 = df.parse('J5B', header =5)
df2.head(50)
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                Wajaran:     Weight:        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                2017        NaN
# 6                                                2018        NaN
# 7                                                2019        NaN
# 8                                                2020        NaN
# 9                                                2021        NaN
# 10                                                NaN        NaN
# 11                                               2020        JAN
# 12                                                NaN        FEB
# ...

# %%
df2.iloc[24][2]
# Out:
# -0.2

# %%
print(df2.iloc[24][0])

for i in range(24, 36):
    print(df2.iloc[i][1])
    for j in range(3, 15):
        print(df2.iloc[i][j])
# Out:
# 2021
# JAN
# 1.5
# 0.7
# -0.4
# -0.7
# 0.2
# 0.7
# -5.1
# 0.0
# 0.1
# 0.2
# -0.1
# 1.8
# FEB
# 1.4
# 0.7
# -0.4
# -0.8
# 0.3
# 0.7
# -2.0
# 0.0
# 0.1
# 0.1
# -0.3
# 1.6
# MAC
# 1.5
# 0.6
# -0.3
# -0.8
# 0.9
# 0.5
# 9.8
# 0.0
# 0.5
# 0.0
# 0.0
# 1.0
# APR
# 1.9
# 0.7
# -0.4
# 3.1
# 1.6
# 0.5
# 27.0
# 0.0
# 0.7
# 0.2
# 0.2
# 1.2
# MEI
# 1.5
# 0.7
# -0.5
# 3.2
# 2.1
# 0.6
# 26.0
# 0.0
# 0.6
# 0.3
# 0.2
# 0.7
# JUN
# 1.3
# 0.7
# -0.4
# 3.2
# 2.0
# 0.5
# 16.6
# 0.0
# 0.6
# 0.5
# 0.5
# 0.3
# JUL
# 1.3
# 0.5
# -0.4
# 0.7
# 1.7
# 0.4
# 11.6
# 0.0
# 0.6
# 0.1
# 0.7
# 0.1
# OGO
# 1.2
# 0.4
# -0.4
# 0.6
# 1.7
# 0.3
# 11.0
# 0.0
# 0.7
# 0.0
# 0.6
# -0.6
# SEP
# 1.9
# 0.4
# -0.5
# 0.7
# 1.7
# 0.3
# 11.0
# 0.0
# 0.6
# -0.1
# 0.3
# -0.5
# OKT
# 1.9
# 0.3
# -0.4
# 3.2
# 2.1
# 0.2
# 11.3
# 0.0
# 0.2
# -0.1
# 0.6
# -0.2
# NOV
# 2.7
# 0.3
# -0.4
# 3.4
# 2.6
# 0.2
# 12.7
# 0.0
# 0.2
# 0.1
# 0.9
# 0.1
# DIS
# 3.2
# 0.3
# -0.4
# 3.4
# 2.7
# 0.2
# 9.5
# 0.0
# 0.4
# 0.2
# 1.3
# 0.4

# %%
print(df2.iloc[11][0])

for i in range(11, 23):
    print(df2.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        print(df2.iloc[i][j], items_id)
        items_id +=1
# Out:
# 2020
# JAN
# 0.9 1
# 0.1 2
# -1.2 3
# 1.7 4
# 1.2 5
# 1.4 6
# 3.9 7
# 1.5 8
# 0.9 9
# 1.7 10
# 1.1 11
# 2.5 12
# FEB
# 0.8 1
# 0.2 2
# -1.1 3
# 1.6 4
# 1.0 5
# 1.3 6
# 2.4 7
# 1.5 8
# 0.7 9
# 1.3 10
# 1.1 11
# 2.5 12
# MAC
# 1.2 1
# 0.3 2
# -1.3 3
# 1.6 4
# 0.8 5
# 1.4 6
# -8.9 7
# 1.5 8
# 0.7 9
# 1.3 10
# 0.9 11
# 2.6 12
# APR
# 1.2 1
# 0.2 2
# -1.2 3
# -2.2 4
# 0.3 5
# 1.2 6
# -21.5 7
# 1.6 8
# 0.6 9
# 1.2 10
# 0.7 11
# 2.3 12
# MEI
# 1.2 1
# 0.2 2
# -1.1 3
# -2.6 4
# -0.2 5
# 1.2 6
# -20.8 7
# 1.6 8
# 0.7 9
# 1.0 10
# 0.9 11
# 2.8 12
# JUN
# 1.6 1
# 0.2 2
# -1.1 3
# -2.6 4
# -0.2 5
# 1.1 6
# -14.3 7
# 1.6 8
# 0.6 9
# 0.8 10
# 0.3 11
# 3.0 12
# JUL
# 1.4 1
# 0.3 2
# -0.6 3
# -2.6 4
# -0.1 5
# 1.1 6
# -10.3 7
# 1.6 8
# 0.7 9
# 1.2 10
# 0.2 11
# 2.9 12
# OGO
# 1.3 1
# 0.3 2
# -0.6 3
# -3.0 4
# -0.1 5
# 1.1 6
# -9.9 7
# 1.6 8
# 0.6 9
# 1.1 10
# 0.1 11
# 3.1 12
# SEP
# 1.4 1
# 0.5 2
# -0.6 3
# -3.0 4
# 0.1 5
# 1.1 6
# -9.9 7
# 1.6 8
# 0.1 9
# 0.7 10
# 0.1 11
# 2.7 12
# OKT
# 1.5 1
# ...

# %%
df3 = df.parse('J5C', header =5)
df3.head(40)
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                Wajaran:     Weight:        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                2020        JAN
# 6                                                 NaN        FEB
# 7                                                 NaN        MAC
# 8                                                 NaN        APR
# 9                                                 NaN        MEI
# 10                                                NaN        JUN
# 11                                                NaN        JUL
# 12                                                NaN        OGO
# ...

# %%
print(df3.iloc[5][0])

for i in range(5, 17):
    print(df3.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        print(df3.iloc[i][j], items_id)
        items_id +=1
# Out:
# 2020
# JAN
# 0.1 1
# -0.1 2
# -0.1 3
# 0.0 4
# 0.0 5
# 0.2 6
# 0.1 7
# 0.0 8
# 0.2 9
# 0.4 10
# 0.1 11
# 0.4 12
# FEB
# 0.1 1
# 0.1 2
# 0.0 3
# 0.3 4
# 0.1 5
# 0.1 6
# -1.0 7
# 0.0 8
# 0.0 9
# 0.1 10
# 0.2 11
# -0.1 12
# MAC
# -0.1 1
# 0.1 2
# -0.1 3
# 0.0 4
# 0.0 5
# 0.3 6
# -8.7 7
# 0.0 8
# -0.1 9
# 0.0 10
# -0.2 11
# 0.4 12
# APR
# -0.1 1
# 0.0 2
# 0.0 3
# -3.8 4
# -0.4 5
# 0 6
# -13.5 7
# 0.0 8
# 0.0 9
# -0.1 10
# 0.0 11
# -0.2 12
# MEI
# 0.3 1
# 0.1 2
# 0.0 3
# -0.1 4
# -0.2 5
# 0 6
# 1.0 7
# 0.0 8
# 0.0 9
# -0.1 10
# 0.1 11
# 0.5 12
# JUN
# 0.4 1
# 0.1 2
# -0.1 3
# 0.0 4
# 0.1 5
# 0.1 6
# 7.8 7
# 0.0 8
# 0.0 9
# -0.2 10
# -0.4 11
# 0.4 12
# JUL
# 0.1 1
# 0.1 2
# 0.0 3
# 0.0 4
# 0.3 5
# 0.1 6
# 4.9 7
# 0.0 8
# 0.0 9
# 0.4 10
# -0.1 11
# 0.3 12
# OGO
# 0.1 1
# 0.1 2
# 0.0 3
# 0.2 4
# 0.0 5
# 0.1 6
# 0.4 7
# 0.0 8
# -0.1 9
# 0.0 10
# 0.1 11
# 0.7 12
# SEP
# -0.1 1
# 0.1 2
# 0.0 3
# 0.0 4
# 0.1 5
# 0 6
# 0.0 7
# 0.0 8
# 0.1 9
# 0.1 10
# 0.2 11
# 0.0 12
# OKT
# 0.1 1
# 0.0 2
# ...

# %%
print(df3.iloc[18][0])

for i in range(18, 30):
    print(df3.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        print(df3.iloc[i][j], items_id)
        items_id +=1
# Out:
# 2021
# JAN
# 0.2 1
# 0.1 2
# -0.1 3
# 2.6 4
# 0.3 5
# 0 6
# 3.7 7
# 0.0 8
# 0.1 9
# 0.0 10
# 0.2 11
# 0.1 12
# FEB
# 0 1
# 0.0 2
# 0.0 3
# 0.2 4
# 0.2 5
# 0.1 6
# 2.3 7
# 0.0 8
# 0.0 9
# 0.0 10
# -0.1 11
# -0.3 12
# MAC
# 0 1
# 0.1 2
# 0.0 3
# 0.0 4
# 0.6 5
# 0.1 6
# 2.3 7
# 0.0 8
# 0.4 9
# -0.1 10
# 0.1 11
# -0.2 12
# APR
# 0.3 1
# 0.1 2
# -0.1 3
# 0.1 4
# 0.3 5
# 0 6
# 0.1 7
# 0.0 8
# 0.2 9
# 0.2 10
# 0.2 11
# 0.1 12
# MEI
# -0.1 1
# 0.1 2
# -0.1 3
# 0.0 4
# 0.3 5
# 0.1 6
# 0.2 7
# 0.0 8
# -0.1 9
# 0.0 10
# 0.1 11
# 0.0 12
# JUN
# 0.3 1
# 0.1 2
# 0.0 3
# 0.0 4
# 0.0 5
# 0 6
# -0.2 7
# 0.0 8
# 0.0 9
# 0.0 10
# 0.0 11
# 0.1 12
# JUL
# 0 1
# -0.1 2
# 0.0 3
# -2.5 4
# 0.0 5
# 0 6
# 0.3 7
# 0.0 8
# 0.0 9
# 0.0 10
# 0.1 11
# 0.0 12
# OGO
# 0.1 1
# 0.0 2
# 0.0 3
# 0.1 4
# 0.0 5
# 0 6
# -0.1 7
# 0.0 8
# 0.0 9
# -0.1 10
# 0.0 11
# 0.0 12
# SEP
# 0.6 1
# 0.1 2
# -0.1 3
# 0.1 4
# 0.1 5
# 0 6
# 0.0 7
# 0.0 8
# 0.0 9
# 0.0 10
# -0.2 11
# 0.1 12
# OKT
# 0.2 1
# -0.1 2
# 0.0 3
# 2.5 4
# 0.4 5
# ...

# %%
#df1.tail(40)

# %%
#df1.iloc[18,6]

# %%
#df1.iloc[18,8]

# %%
#df1.iloc[62,8]

# %%
#df1.iloc[62,6]

# %%
#print(df1.iloc[18,8],df1.iloc[18,6])

# %%
#print('\033[1m', 'hi')

# %%
df1.iloc[17,8]
# Out:
# 'Total'

# %%
print('\033[1m','Annual CPI changes of items: ', '\033[0m')
cpi_annual = []
for i in range(18, 30):
    print(df1.iloc[i,8],df1.iloc[i,6],'%')
    cpi_annual.append([df1.iloc[i,8],df1.iloc[i,6]])

for i in range(61,74):
    print(df1.iloc[i,8],df1.iloc[i,6],'%')
    cpi_annual.append([df1.iloc[i,8],df1.iloc[i,6]])
# Out:
#  Annual CPI changes of items:
# Food & Non-Alcoholic Beverages 3.1664212076583085 %
# Alcoholic Beverages & Tobacco 0.2962085308056872 %
# Clothing & Footwear -0.4282655246252738 %
# Housing, Water, Electricity, Gas & Other Fuels 3.3840947546531304 %
# Furnishings, Household Equipment & Routine Household Maintenance 2.739726027397263 %
# Health 0.2411575562700942 %
# Transport 9.505703422053232 %
# Communication 0 %
# Recreation Services & Culture 0.4448398576512455 %
# Education 0.16528925619834947 %
# Restaurants & Hotels 1.284958427815562 %
# Miscellaneous Goods & Services 0.42844901456726653 %
# Food 3.3625730994152003 %
# Food At Home 4.147812971342383 %
# 011 Rice, Bread & Other Cereals 1.341681574239714 %
# 012 Meat 8.31353919239906 %
# 013 Fish & Seafood 4.188144329896907 %
# 014 Milk, Cheese & Eggs 5.537720706260036 %
# 015 Oils & Fats 4.409317803660564 %
# 016 Fruits 1.772525849335307 %
# 017 Vegetables 4.999999999999992 %
# ...

# %%
print('\033[1m','Monthly CPI changes of items: ', '\033[0m')
cpi_monthly = []
for i in range(18, 30):
    print(df1.iloc[i,8],df1.iloc[i,5],'%')
    cpi_monthly.append([df1.iloc[i,8],df1.iloc[i,5]])

for i in range(61,74):
    print(df1.iloc[i,8],df1.iloc[i,5],'%')
    cpi_monthly.append([df1.iloc[i,8],df1.iloc[i,5]])
# Out:
#  Monthly CPI changes of items:
# Food & Non-Alcoholic Beverages 1.009372746935837 %
# Alcoholic Beverages & Tobacco 0 %
# Clothing & Footwear 0 %
# Housing, Water, Electricity, Gas & Other Fuels 0 %
# Furnishings, Household Equipment & Routine Household Maintenance 0.2506265664160377 %
# Health 0 %
# Transport 0.08688097306690576 %
# Communication 0 %
# Recreation Services & Culture 0.266429840142106 %
# Education 0.08257638315442488 %
# Restaurants & Hotels 0.37453183520599254 %
# Miscellaneous Goods & Services 0.17094017094017336 %
# Food 1.072194424588992 %
# Food At Home 1.3206162876008678 %
# 011 Rice, Bread & Other Cereals 0.6216696269982264 %
# 012 Meat 0.29325513196481356 %
# 013 Fish & Seafood 1.2523481527864748 %
# 014 Milk, Cheese & Eggs 1.937984496124031 %
# 015 Oils & Fats 0.48038430744595223 %
# 016 Fruits 0.8046817849305214 %
# 017 Vegetables 4.419889502762415 %
# 018 Sugar, Jam, Honey, Chocolate & Confectionery 0.07407407407406986 %
# ...

# %%
#for i in range(62,74):
#    print(df1.iloc[i,8],df1.iloc[i,6])

# %%
df_cpi_annual = pd.DataFrame(cpi_annual, columns=['Items', 'Changes'])

# %%
df_cpi_annual
# Out:
#                                                 Items   Changes
# 0                      Food & Non-Alcoholic Beverages  3.166421
# 1                       Alcoholic Beverages & Tobacco  0.296209
# 2                                 Clothing & Footwear -0.428266
# 3      Housing, Water, Electricity, Gas & Other Fuels  3.384095
# 4   Furnishings, Household Equipment & Routine Hou...  2.739726
# 5                                              Health  0.241158
# 6                                           Transport  9.505703
# 7                                       Communication  0.000000
# 8                       Recreation Services & Culture  0.444840
# 9                                           Education  0.165289
# 10                               Restaurants & Hotels  1.284958
# 11                     Miscellaneous Goods & Services  0.428449
# 12                                               Food  3.362573
# 13                                       Food At Home  4.147813
# ...

# %%
df_cpi_monthly = pd.DataFrame(cpi_monthly, columns=['Items', 'Changes'])

# %%
df_cpi_monthly
# Out:
#                                                 Items   Changes
# 0                      Food & Non-Alcoholic Beverages  1.009373
# 1                       Alcoholic Beverages & Tobacco  0.000000
# 2                                 Clothing & Footwear  0.000000
# 3      Housing, Water, Electricity, Gas & Other Fuels  0.000000
# 4   Furnishings, Household Equipment & Routine Hou...  0.250627
# 5                                              Health  0.000000
# 6                                           Transport  0.086881
# 7                                       Communication  0.000000
# 8                       Recreation Services & Culture  0.266430
# 9                                           Education  0.082576
# 10                               Restaurants & Hotels  0.374532
# 11                     Miscellaneous Goods & Services  0.170940
# 12                                               Food  1.072194
# 13                                       Food At Home  1.320616
# ...

# %%
#len(df_cpi.iloc[4,0])

# %%
for i in range(18, 30):
    print(df1.iloc[i,8])

print(df1.iloc[17, 8])
# Out:
# Food & Non-Alcoholic Beverages
# Alcoholic Beverages & Tobacco
# Clothing & Footwear
# Housing, Water, Electricity, Gas & Other Fuels
# Furnishings, Household Equipment & Routine Household Maintenance
# Health
# Transport
# Communication
# Recreation Services & Culture
# Education
# Restaurants & Hotels
# Miscellaneous Goods & Services
# Total

# %%
"""
## THis command is to fill up CPI items ID

import pyodbc

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:

for i in range(18, 30):
    cursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", df1.iloc[i,8])

    #print(df1.iloc[i,8])
    
cursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", df1.iloc[17,8])

#print(df1.iloc[17, 8])

#for index, row in df_cpi_annual.iterrows():
#     cursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", row.Items)
cnxn.commit()
cursor.close()

"""
# Out:
# '\n## THis command is to fill up CPI items ID\n\nimport pyodbc\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n\nfor i in range(18, 30):\n    cursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", df1.iloc[i,8])\n\n    #print(df1.iloc[i,8])\n    \ncursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", df1.iloc[17,8])\n\n#print(df1.iloc[17, 8])\n\n#for index, row in df_cpi_annual.iterrows():\n#     cursor.execute("INSERT INTO Economy.CPI_ID (CPI_items) values(?)", row.Items)\ncnxn.commit()\ncursor.close()\n\n'

# %%
"""
import pyodbc, os
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

for index, row in df_cpi.iterrows():
    cursor.execute("INSERT INTO Economy.CPI (Indicator_ID, Items_ID,Country_ID, Year, Changes_percentage, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?)",
                    3, index+1,1, int(latest_year),row.Changes, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)
cnxn.commit()
cursor.close()

"""
# Out:
# '\nimport pyodbc, os\nfrom datetime import date, datetime\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_gdp.iterrows():\n   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n    #                index+1, row.AnnualGrowthRate)\n\nfor index, row in df_cpi.iterrows():\n    cursor.execute("INSERT INTO Economy.CPI (Indicator_ID, Items_ID,Country_ID, Year, Changes_percentage, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?)",\n                    3, index+1,1, int(latest_year),row.Changes, datetime.now().strftime(\'%Y/%m/%d %H:%M:%S\'),1, datetime.now().
# ...

# %%
#for index, row in df_cpi.iterrows():
 #       print(index+1, row.Items, row.Changes)

# %%
def monthToNum(shortMonth):
    return {
            'JAN': 1,
            'FEB': 2,
            'MAC': 3,
            'APR': 4,
            'MEI': 5,
            'JUN': 6,
            'JUL': 7,
            'OGO': 8,
            'SEP': 9, 
            'OKT': 10,
            'NOV': 11,
            'DIS': 12
    }[shortMonth]

# %%
latest_month = df.parse(0).iloc[2].dropna()[1]
latest_month
# Out:
# 'DIS'

# %%
monthToNum(latest_month)
# Out:
# 12

# %%
"""
import pyodbc, os
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

#for index, row in df_cpi.iterrows():
#    cursor.execute("INSERT INTO Economy.CPI (Indicator_ID, Items_ID,Country_ID, Year, Changes_percentage, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?)",
#                    3, index+1,1, int(latest_year),row.Changes, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)

for index, row in df_cpi_annual.iterrows():
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(index+1)+' , @Country_ID= 1 ,@Year='+str(latest_year)+', @Month = '+str(monthToNum(latest_month))+', @Changes_percentage='+ str(row.Changes)+', @Is_M2M =0')

for index, row in df_cpi_monthly.iterrows():
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(index+1)+' , @Country_ID= 1 ,@Year='+str(latest_year)+', @Month = '+str(monthToNum(latest_month))+', @Changes_percentage='+ str(row.Changes)+', @Is_M2M =1')

    
cnxn.commit()
cursor.close()

"""
# Out:
# '\nimport pyodbc, os\nfrom datetime import date, datetime\n\nserver = \'DESKTOP-U753JSI\' \ndatabase = \'Economic\' \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';Trusted_Connection = yes\')\ncursor = cnxn.cursor()\n# Insert Dataframe into SQL Server:\n#for index, row in df_gdp.iterrows():\n   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",\n    #                index+1, row.AnnualGrowthRate)\n\n#for index, row in df_cpi.iterrows():\n#    cursor.execute("INSERT INTO Economy.CPI (Indicator_ID, Items_ID,Country_ID, Year, Changes_percentage, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?)",\n#                    3, index+1,1, int(latest_year),row.Changes, datetime.now().strftime(\'%Y/%m/%d %H:%M:%S\'),1, datetime.now
# ...

# %%
df3
# Out:
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                Wajaran:     Weight:        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                2020        JAN
# 6                                                 NaN        FEB
# 7                                                 NaN        MAC
# 8                                                 NaN        APR
# 9                                                 NaN        MEI
# 10                                                NaN        JUN
# 11                                                NaN        JUL
# 12                                                NaN        OGO
# ...

# %% [markdown]
# Push data into SQLite database

# %%
import sqlite3
from sqlite3 import Error

#Create table

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)


def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    sql_create_CPI_table = """ CREATE TABLE IF NOT EXISTS CPI (
                                        ID INTEGER PRIMARY KEY,
                                        Indicator_ID smallint NOT NULL,
                                        Items_ID smallint NOT NULL,
                                        Country_ID smallint NOT NULL,
                                        Year smallint NOT NULL,
                                        Month smallint NOT NULL,
                                        Changes_percentage float,
                                        Is_M2M bit,
                                        Date_Created datetime,
                                        Created_By smallint NOT NULL,
                                        Date_Modified datetime,
                                        Modified_By,
                                        Is_Active bit NOT NULL,
                                        Is_Delete bit NOT NULL
                                        
                                    ); """

   
    # create a database connection
    conn = create_connection(database)

    # create tables
    if conn is not None:
        # create projects table
        create_table(conn, sql_create_CPI_table)

        # create tasks table
       # create_table(conn, sql_create_tasks_table)
    else:
        print("Error! cannot create the database connection.")


if __name__ == '__main__':
    main()

# %%
import sqlite3
from sqlite3 import Error
from datetime import date, datetime


# Insert data
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def create_CPI(conn, CPI):
    """
    Create a new project into the  table
    :param conn:
    :param :
    :return:  id
    """
    sql = ''' INSERT INTO CPI(Indicator_ID, Items_ID, Country_ID, Year, Month, Changes_percentage, Is_M2M, Date_Created, Created_By, Date_Modified, Modified_By, Is_Active, Is_Delete)
              VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, CPI)
    conn.commit()
    return cur.lastrowid





def main():
    database = r"C:\Users\zhenl\Desktop\New Shiny App\new\economic.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        
        for i in range(11, 23):
            items_id = 1
            for j in range(3, 15):
                CPI = (3, items_id, 1, 2020, monthToNum(df2.iloc[i][1]), df2.iloc[i][j], 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_CPI(conn, CPI)
                       
                items_id +=1
            CPI = (3, items_id, 1, 2020, monthToNum(df2.iloc[i][1]), df2.iloc[i][2], 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_CPI(conn, CPI)

        for i in range(24, 36):
            items_id = 1
            for j in range(3, 15):
                CPI = (3, items_id, 1, 2021, monthToNum(df2.iloc[i][1]), df2.iloc[i][j], 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_CPI(conn, CPI)
                       
                items_id +=1
            CPI = (3, items_id, 1, 2021, monthToNum(df2.iloc[i][1]), df2.iloc[i][2], 0, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_CPI(conn, CPI)  
            
        for i in range(5, 17):
            items_id = 1
            for j in range(3, 15):
                CPI = (3, items_id, 1, 2020, monthToNum(df3.iloc[i][1]), df3.iloc[i][j], 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_CPI(conn, CPI)
                       
                items_id +=1
            CPI = (3, items_id, 1, 2020, monthToNum(df3.iloc[i][1]), df3.iloc[i][2], 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_CPI(conn, CPI)
         
        for i in range(18, 30):
            items_id = 1
            for j in range(3, 15):
                CPI = (3, items_id, 1, 2021, monthToNum(df3.iloc[i][1]), df3.iloc[i][j], 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
                create_CPI(conn, CPI)
                       
                items_id +=1
            CPI = (3, items_id, 1, 2021, monthToNum(df3.iloc[i][1]), df3.iloc[i][2], 1, '-', 1, datetime.now().strftime('%Y/%m/%d'),1,1,0 );
            create_CPI(conn, CPI)
       
            
            
            
            

if __name__ == '__main__':
    main()

# %%
for i in range(18, 30):
    print(df1.iloc[i,8])

print(df1.iloc[17,8])
# Out:
# Food & Non-Alcoholic Beverages
# Alcoholic Beverages & Tobacco
# Clothing & Footwear
# Housing, Water, Electricity, Gas & Other Fuels
# Furnishings, Household Equipment & Routine Household Maintenance
# Health
# Transport
# Communication
# Recreation Services & Culture
# Education
# Restaurants & Hotels
# Miscellaneous Goods & Services
# Total

# %%
len(df1.iloc[22,8])
# Out:
# 64

# %% [markdown]
# Push data into SQL server

# %%
import pyodbc, os
from datetime import date, datetime

server = 'DESKTOP-U753JSI' 
database = 'Economic' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection = yes')
cursor = cnxn.cursor()
# Insert Dataframe into SQL Server:
#for index, row in df_gdp.iterrows():
   #  cursor.execute("INSERT INTO Economy.GDPRecord (Indicator_ID,Sector_ID,Country_ID, Year,Quarter, Value,Is_Q2Q,Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?,?,?)",
    #                index+1, row.AnnualGrowthRate)

#for index, row in df_cpi.iterrows():
#    cursor.execute("INSERT INTO Economy.CPI (Indicator_ID, Items_ID,Country_ID, Year, Changes_percentage, Date_Created, Created_By,Date_Modified, Modified_By, Is_Active, Is_Delete) values(?,?,?,?,?,?,?,?,?,?,?)",
#                    3, index+1,1, int(latest_year),row.Changes, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1, datetime.now().strftime('%Y/%m/%d %H:%M:%S'),1,1,0)


for i in range(11, 23):
    #print(df2.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2020, @Month = '+str(monthToNum(df2.iloc[i][1]))+', @Changes_percentage='+ str(df2.iloc[i][j])+', @Is_M2M =0')
        items_id +=1
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2020, @Month = '+str(monthToNum(df2.iloc[i][1]))+', @Changes_percentage='+ str(df2.iloc[i][2])+', @Is_M2M =0')

        #print(df2.iloc[i][j])

for i in range(24, 36):
    #print(df2.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2021, @Month = '+str(monthToNum(df2.iloc[i][1]))+', @Changes_percentage='+ str(df2.iloc[i][j])+', @Is_M2M =0')
        items_id +=1
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2021, @Month = '+str(monthToNum(df2.iloc[i][1]))+', @Changes_percentage='+ str(df2.iloc[i][2])+', @Is_M2M =0')
  
        #print(df2.iloc[i][j])

for i in range(5, 17):
    #print(df3.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2020, @Month = '+str(monthToNum(df3.iloc[i][1]))+', @Changes_percentage='+ str(df3.iloc[i][j])+', @Is_M2M =1')
        items_id +=1  
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2020, @Month = '+str(monthToNum(df3.iloc[i][1]))+', @Changes_percentage='+ str(df3.iloc[i][2])+', @Is_M2M =1')


for i in range(18, 30):
    #print(df3.iloc[i][1])
    items_id = 1
    for j in range(3, 15):
        cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2021, @Month = '+str(monthToNum(df3.iloc[i][1]))+', @Changes_percentage='+ str(df3.iloc[i][j])+', @Is_M2M =1')
        items_id +=1 
    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(items_id)+' , @Country_ID= 1 ,@Year= 2021, @Month = '+str(monthToNum(df3.iloc[i][1]))+', @Changes_percentage='+ str(df3.iloc[i][2])+', @Is_M2M =1')
        
#for index, row in df_cpi_annual.iterrows():
#    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(index+1)+' , @Country_ID= 1 ,@Year=2021, @Month = '+str(monthToNum(latest_month))+', @Changes_percentage='+ str(row.Changes)+', @Is_M2M =0')

#for index, row in df_cpi_monthly.iterrows():
#    cursor.execute('[dbo].[SP_CPI_I_220117] @Indicator_ID = 3 , @Items_ID = '+str(index+1)+' , @Country_ID= 1 ,@Year=2021, @Month = '+str(monthToNum(latest_month))+', @Changes_percentage='+ str(row.Changes)+', @Is_M2M =1')

        
        


    
cnxn.commit()
cursor.close()
